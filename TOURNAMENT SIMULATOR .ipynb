# %%
import pandas
import numpy
import requests
import bs4
import nose.tools
import random 
from statistics import mean

# %%
def game_simulator(team1, team2):  
    team1score = 0 
    team2score = 0 
    url = 'https://www.sports-reference.com/cbb/schools/' +team1 + '/2019.html#all_per_game'
    page = requests.get(url)
    f = open('downloaded.html','w', encoding = "utf-8")
    f.write(page.text)
    soup = bs4.BeautifulSoup(open("downloaded.html"), 'html.parser')
    SRS1 =int((str(soup.find_all('p')[6]).split("/strong>")[1].split("(")[1].replace("st", " ").replace("nd", " ").replace("rd", " ").replace("th", " ")).split()[0])
    tables = soup.find_all('table')
    table = tables[2]
    
    teamTable1 = tables[1]
    rows = teamTable1.find_all('tr')
    
    defense1 = []    
    i = 0
    
    for row in rows:
        j = 0
        columns = row.find_all('td')
        row = []
        for column in columns:
            text = column.string
            row.append(text)
        defense1.append(row)
    defence1 = pandas.DataFrame(defense1, columns = ['G', 'MP', 'FG', 'FGA','FG%', '2P', '2PA', '2P%', '3P', '3PA', '3P%', 'FT','FTA', 'FT%','ORB','DRB', 'TRB', 'AST', 'STL','BLK','TOV', 'PF','PTS', 'PTS/G'])    
    
    
    
    
    
    SRSmax = 353
    
    
    
    
    
    rows = table.find_all('tr')
    data = [] 
    i = 0
    for row in rows:
        j = 0
        columns = row.find_all('td')
        row = []
        for column in columns:
            text = column.string
            row.append(text)
        data.append(row)
    data = pandas.DataFrame(data, columns = ["Name", "G", "GS", "MP", "FG", "FGA", "FG%", "2P","2PA", "2P%", "3P", "3PA", "3P%", "FT", 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'])
    data = data.iloc[1:]
    

    for column in data.columns: 
        if column != "Name":
            data[column] = pandas.to_numeric(data[column])
    boxScore = pandas.DataFrame(columns = ['Name', 'Points', '2PM', '2PA', '3PM', '3PA', 'TOV', "ORB", "DRB", "TRB"])
    boxScore['Name'] = data['Name']
    boxScore = boxScore.fillna(0)

    url = 'https://www.sports-reference.com/cbb/schools/' +team2 + '/2019.html#all_per_game'
    page = requests.get(url)
    f = open('downloaded.html','w', encoding = "utf-8")
    f.write(page.text)
    soup = bs4.BeautifulSoup(open("downloaded.html"), 'html.parser')
    SRS2 =int((str(soup.find_all('p')[6]).split("/strong>")[1].split("(")[1].replace("st", " ").replace("nd", " ").replace("rd", " ").replace("th", " ")).split()[0] )
    tables = soup.find_all('table')
    
    teamTable2 = tables[1]
    rows = teamTable2.find_all('tr')
    
    defense2 = []    
    i = 0
    for row in rows:
        j = 0
        columns = row.find_all('td')
        row = []
        for column in columns:
            text = column.string
            row.append(text)
        defense2.append(row)
    defence2 = pandas.DataFrame(defense2, columns = ['G', 'MP', 'FG', 'FGA','FG%', '2P', '2PA', '2P%', '3P', '3PA', '3P%', 'FT','FTA', 'FT%','ORB','DRB', 'TRB', 'AST', 'STL','BLK','TOV', 'PF','PTS', 'PTS/G'])    

    
    
    table = tables[2]
    rows = table.find_all('tr')
    data2 = [] 
    i = 0
    for row in rows:
        j = 0
        columns = row.find_all('td')
        row = []
        for column in columns:
            text = column.string
            row.append(text)
        data2.append(row)
    data2 = pandas.DataFrame(data2, columns = ["Name", "G", "GS", "MP", "FG", "FGA", "FG%", "2P","2PA", "2P%", "3P", "3PA", "3P%", "FT", 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'])
    data2 = data2.iloc[1:]
    

    for column in data2.columns: 
        if column != "Name":
            data2[column] = pandas.to_numeric(data2[column])
    boxScore2 = pandas.DataFrame(columns = ['Name', 'Points', '2PM', '2PA', '3PM', '3PA', 'TOV',"ORB", "DRB", "TRB"])
    boxScore2['Name'] = data2['Name']
    boxScore2 = boxScore2.fillna(0)


    SRScoeff1 = .2+ (.8*((SRSmax-SRS1)/(SRSmax-1)))
    SRScoeff2 = .2 + (.8*((SRSmax-SRS2)/(SRSmax-1)))
    
    

    for ghe in range(0,1):
        time = 40*60 
        score1 = 0
        score2 = 0 
        turnovers1 = 0
        turnovers2 = 0 
        pos = 1
        while time > 0: 
            if(pos == 1):
                
                FGA = data.FGA.sum()
                TOV = data.TOV.sum()
                FGA2 = data["2PA"].sum()
                FGM2 = data["2P"].sum()
                FGA3 = data["3PA"].sum()
                FGM3 = data["3P"].sum()
                Drebound = data2["DRB"].sum()*SRScoeff2
                Orebound = data["ORB"].sum()*SRScoeff1
                oppTeamTOV = float(defence2.loc[3, "TOV"])/float(defence2.loc[3, "G"])  #TOV/G other team forces
                oppDTeam2PA = float(defence2.loc[3, "2PA"])/float(defence2.loc[3, "G"]) #2PA/G other team allows
                oppDTeam3PA = float(defence2.loc[3, "3PA"])/float(defence2.loc[3, "G"]) #3PA/G other team allows 
                oppDTeam2Per = float(defence2.loc[3, "2P%"])
                oppDTeam3Per = float(defence2.loc[3, "3P%"])
                
                
    
                print(oppTeamTOV)
                cof1 = 100* (FGA/(FGA+(TOV+oppTeamTOV)/2)) #percent of possesions that result in shot attempt. 
                rand1 = random.randint(1,101) 
                if(cof1 >= rand1):
                    cof2 = 100*((FGA2 + oppDTeam2PA)/(FGA2 + FGA3+ oppDTeam2PA + oppDTeam3PA)) #percent of shot attempts that are 2 point FG
                    rand2 = random.randint(1,101) 
                    if(cof2  >= rand2):
                        cof3 = SRScoeff1*100*((FGM2/(FGA2)) + oppDTeam2Per)/2 #percent of 2PT FG that go in 
                        rand3 = random.randint(1,101)
                        if(cof3 >= rand3): #Checking if 2PT FG is missed 
                            picked = 0 
                            while picked == 0: #Picking 2PT FG maker
                                rand4 = random.randint(1,data.shape[0]-1) 
                                rand5 = random.randint(1,101)
                                cof4 = 100 *(data.loc[rand4, "2P"]/FGM2)
                                if(cof4 >= rand5):
                                    picked = 1
                                    print("2PT FG by " + data.loc[rand4, "Name"])
                                    boxScore.at[rand4, "2PM"] = boxScore.loc[rand4, "2PM"] + 1
                                    boxScore.at[rand4, "2PA"] = boxScore.loc[rand4, "2PA"] + 1
                                    boxScore.at[rand4, "Points"] = boxScore.loc[rand4, "Points"] + 2
                                    score1 = score1 + 2
                                    pos = 2

                        else:
                            picked = 0 
                            while picked == 0: #Picking 2PT FG misser
                                rand4 = random.randint(1,data.shape[0]-1) 
                                rand5 = random.randint(1,101)
                                cof4 = 100 *((data.loc[rand4, "2PA"] - data.loc[rand4, "2P"])/(FGA2- FGM2))
                                if(cof4 >= rand5):
                                    picked = 1
                                    print("2PT FG missed by " + data.loc[rand4, "Name"])
                                    boxScore.at[rand4, "2PA"] = boxScore.loc[rand4, "2PA"] + 1
                                    offRebound = 100 *(Orebound/(Drebound + Orebound)) #offensive rebounding rate for team 
                                    randomRebound = random.randint(1,101)
                                    if(offRebound >= randomRebound):
                                        pos = 1
                                        picked = 0 
                                        while picked == 0: #Picking offensive rebounder
                                            rand4 = random.randint(1,data.shape[0]-1) 
                                            rand5 = random.randint(1,101)
                                            cof4 = 100 *(data.loc[rand4, "ORB"]/Orebound)
                                            if(cof4 >= rand5):
                                                picked = 1
                                                print("Offensive rebound by " + data.loc[rand4, "Name"])
                                                boxScore.at[rand4, "ORB"] = boxScore.loc[rand4, "ORB"] + 1
                                                boxScore.at[rand4, "TRB"] = boxScore.loc[rand4, "TRB"] + 1

                                    else: #picking defensive rebounder for opposing team
                                        pos = 2
                                        picked = 0 
                                        while picked == 0: #Picking defensive rebounder for the opposing team 
                                            rand4 = random.randint(1,data2.shape[0]-1) 
                                            rand5 = random.randint(1,101)
                                            cof4 = 100 *(data2.loc[rand4, "DRB"]/Drebound)
                                            if(cof4 >= rand5):
                                                picked = 1
                                                print("Defensive rebound by " + data2.loc[rand4, "Name"])
                                                boxScore2.at[rand4, "DRB"] = boxScore2.loc[rand4, "DRB"] + 1
                                                boxScore2.at[rand4, "TRB"] = boxScore2.loc[rand4, "TRB"] + 1



                    else:
                        cof6 = SRScoeff1*100*((FGM3/(FGA3)) + oppDTeam3Per)/2 #percent of 3PT FG that go in 
                        rand6 = random.randint(1,101)
                        if(cof6 >= rand6): #Checking if 3PT FG is missed 
                            picked2 = 0 
                            while picked2 == 0: #Picking 3PT FG maker
                                rand4 = random.randint(1,data.shape[0]-1) 
                                rand5 = random.randint(1,101)
                                cof4 = 100 *(data.loc[rand4, "3P"]/FGM3)
                                if(cof4 >= rand5):
                                    picked2 = 1
                                    print("3PT FG by " + data.loc[rand4, "Name"])
                                    boxScore.at[rand4, "3PM"] = boxScore.loc[rand4, "3PM"] + 1
                                    boxScore.at[rand4, "3PA"] = boxScore.loc[rand4, "3PA"] + 1
                                    boxScore.at[rand4, "Points"] = boxScore.loc[rand4, "Points"] + 3
                                    score1 = score1 + 3
                                    pos = 2
                        else:
                            picked = 0 
                            while picked == 0: #Picking 3PT FG misser
                                rand4 = random.randint(1,data.shape[0]-1) 
                                rand5 = random.randint(1,101)
                                cof4 = 100 *((data.loc[rand4, "3PA"] - data.loc[rand4, "3P"])/(FGA3- FGM3))

                                if(cof4 >= rand5):
                                    picked = 1
                                    print("3PT FG missed by " + data.loc[rand4, "Name"])
                                    boxScore.at[rand4, "3PA"] = boxScore.loc[rand4, "3PA"] + 1
                                    offRebound = 100 *(Orebound/(Drebound + Orebound)) #offensive rebounding rate for team 
                                    randomRebound = random.randint(1,101)
                                    if(offRebound >= randomRebound):
                                        pos = 1
                                        picked = 0 
                                        while picked == 0: #Picking offensive rebounder
                                            rand4 = random.randint(1,data.shape[0]-1) 
                                            rand5 = random.randint(1,101)
                                            cof4 = 100 *(data.loc[rand4, "ORB"]/Orebound)
                                            if(cof4 >= rand5):
                                                picked = 1
                                                print("Offensive rebound by " + data.loc[rand4, "Name"])
                                                boxScore.at[rand4, "ORB"] = boxScore.loc[rand4, "ORB"] + 1
                                                boxScore.at[rand4, "TRB"] = boxScore.loc[rand4, "TRB"] + 1

                                    else: #picking defensive rebounder for opposing team
                                        pos = 2
                                        picked = 0 
                                        while picked == 0: #Picking defensive rebounder for the opposing team 
                                            rand4 = random.randint(1,data2.shape[0]-1) 
                                            rand5 = random.randint(1,101)
                                            cof4 = 100 *(data2.loc[rand4, "DRB"]/Drebound)
                                            if(cof4 >= rand5):
                                                picked = 1
                                                print("Defensive rebound by " + data2.loc[rand4, "Name"])
                                                boxScore2.at[rand4, "DRB"] = boxScore2.loc[rand4, "DRB"] + 1
                                                boxScore2.at[rand4, "TRB"] = boxScore2.loc[rand4, "TRB"] + 1


                else:
                    picked3 = 0 
                    while picked3 == 0:
                        rand4 = random.randint(1,data.shape[0]-1) 
                        rand5 = random.randint(1,101)
                        cof4 = 100 *(data.loc[rand4, "TOV"]/TOV)
                        if(cof4 >= rand5):
                            picked3 = 1
                            turnovers1 = turnovers1 + 1
                            print("Turnover by " + data.loc[rand4, "Name"])
                            boxScore.at[rand4, "TOV"] = boxScore.loc[rand4, "TOV"] + 1
                            pos = 2
            time = time - 15
            if(pos == 2):
                FGAb = data2.FGA.sum()
                TOVb = data2.TOV.sum()
                FGA2b = data2["2PA"].sum()
                FGM2b = data2["2P"].sum()
                FGA3b = data2["3PA"].sum()
                FGM3b = data2["3P"].sum()
                Drebound = data["DRB"].sum()*SRScoeff1
                Orebound = data2["ORB"].sum()*SRScoeff2
                oppTeamTOV = float(defence1.loc[3, "TOV"])/float(defence1.loc[3, "G"])
                oppDTeam2PA = float(defence1.loc[3, "2PA"])/float(defence1.loc[3, "G"]) #2PA/G other team allows
                oppDTeam3PA = float(defence1.loc[3, "3PA"])/float(defence1.loc[3, "G"]) #3PA/G other team allows
                oppDTeam2Per = float(defence1.loc[3, "2P%"])
                oppDTeam3Per = float(defence1.loc[3, "3P%"])
                cof1 = 100* (FGA/(FGA+(TOV+oppTeamTOV)/2)) #percent of possesions that result in shot attempt. 
                rand1 = random.randint(1,101) 
                if(cof1 >= rand1):
                    cof2 = 100*((FGA2 + oppDTeam2PA)/(FGA2 + FGA3+ oppDTeam2PA + oppDTeam3PA)) #percent of shot attempts that are 2 point FG
                    rand2 = random.randint(1,101) 
                    if(cof2  >= rand2):
                        cof3 = SRScoeff2*100*((FGM2/(FGA2)) + oppDTeam2Per)/2 #percent of 2PT FG that go in 
                        rand3 = random.randint(1,101)
                        if(cof3 >= rand3): #Checking if 2PT FG is missed 
                            picked = 0 
                            while picked == 0: #Picking 2PT FG maker
                                rand4 = random.randint(1,data2.shape[0]-1) 
                                rand5 = random.randint(1,101)
                                cof4 = 100 *(data2.loc[rand4, "2P"]/FGM2b)
                                if(cof4 >= rand5):
                                    picked = 1
                                    print("2PT FG by " + data2.loc[rand4, "Name"])
                                    boxScore2.at[rand4, "2PM"] = boxScore2.loc[rand4, "2PM"] + 1
                                    boxScore2.at[rand4, "2PA"] = boxScore2.loc[rand4, "2PA"] + 1
                                    boxScore2.at[rand4, "Points"] = boxScore2.loc[rand4, "Points"] + 2
                                    score2 = score2 + 2
                                    pos = 1 

                        else:
                            picked = 0 
                            while picked == 0: #Picking 2PT FG misser
                                rand4 = random.randint(1,data2.shape[0]-1) 
                                rand5 = random.randint(1,101)
                                cof4 = 100 *((data2.loc[rand4, "2PA"] - data2.loc[rand4, "2P"])/(FGA2b- FGM2b))
                                if(cof4 >= rand5):
                                    picked = 1
                                    print("2PT FG missed by " + data2.loc[rand4, "Name"])
                                    boxScore2.at[rand4, "2PA"] = boxScore2.loc[rand4, "2PA"] + 1
                                    offRebound = 100 *(Orebound/(Drebound + Orebound)) #offensive rebounding rate for team 
                                    randomRebound = random.randint(1,101)
                                    if(offRebound >= randomRebound):
                                        pos = 2
                                        picked = 0 
                                        while picked == 0: #Picking offensive rebounder
                                            rand4 = random.randint(1,data2.shape[0]-1) 
                                            rand5 = random.randint(1,101)
                                            cof4 = 100 *(data2.loc[rand4, "ORB"]/Orebound)
                                            if(cof4 >= rand5):
                                                picked = 1
                                                print("Offensive rebound by " + data2.loc[rand4, "Name"])
                                                boxScore2.at[rand4, "ORB"] = boxScore2.loc[rand4, "ORB"] + 1
                                                boxScore2.at[rand4, "TRB"] = boxScore2.loc[rand4, "TRB"] + 1

                                    else: #picking defensive rebounder for opposing team
                                        pos = 1
                                        picked = 0 
                                        while picked == 0: #Picking defensive rebounder for the opposing team 
                                            rand4 = random.randint(1,data.shape[0]-1) 
                                            rand5 = random.randint(1,101)
                                            cof4 = 100 *(data.loc[rand4, "DRB"]/Drebound)
                                            if(cof4 >= rand5):
                                                picked = 1
                                                print("Defensive rebound by " + data.loc[rand4, "Name"])
                                                boxScore.at[rand4, "DRB"] = boxScore.loc[rand4, "DRB"] + 1
                                                boxScore.at[rand4, "TRB"] = boxScore.loc[rand4, "TRB"] + 1



                    else:
                        cof6 = SRScoeff2*100*((FGM3/(FGA3)) + oppDTeam3Per)/2 #percent of 3PT FG that go in 
                        rand6 = random.randint(1,101)
                        if(cof6 >= rand6): #Checking if 3PT FG is missed 
                            picked2 = 0 
                            while picked2 == 0: #Picking 3PT FG maker
                                rand4 = random.randint(1,data2.shape[0]-1) 
                                rand5 = random.randint(1,101)
                                cof4 = 100 *(data2.loc[rand4, "3P"]/FGM3b)
                                if(cof4 >= rand5):
                                    picked2 = 1
                                    print("3PT FG by " + data2.loc[rand4, "Name"])
                                    boxScore2.at[rand4, "3PM"] = boxScore2.loc[rand4, "3PM"] + 1
                                    boxScore2.at[rand4, "3PA"] = boxScore2.loc[rand4, "3PA"] + 1
                                    boxScore2.at[rand4, "Points"] = boxScore2.loc[rand4, "Points"] + 3
                                    score2 = score2 + 3
                                    pos = 1 
                        else:
                            picked = 0 
                            while picked == 0: #Picking 3PT FG misser
                                rand4 = random.randint(1,data2.shape[0]-1) 
                                rand5 = random.randint(1,101)
                                cof4 = 100 *((data2.loc[rand4, "3PA"] - data2.loc[rand4, "3P"])/(FGA3b- FGM3b))

                                if(cof4 >= rand5):
                                    picked = 1
                                    print("3PT FG missed by " + data2.loc[rand4, "Name"])
                                    boxScore2.at[rand4, "3PA"] = boxScore2.loc[rand4, "3PA"] + 1
                                    offRebound = 100 *(Orebound/(Drebound + Orebound)) #offensive rebounding rate for team 
                                    randomRebound = random.randint(1,101)
                                    if(offRebound >= randomRebound):
                                        pos = 2
                                        picked = 0 
                                        while picked == 0: #Picking offensive rebounder
                                            rand4 = random.randint(1,data2.shape[0]-1) 
                                            rand5 = random.randint(1,101)
                                            cof4 = 100 *(data2.loc[rand4, "ORB"]/Orebound)
                                            if(cof4 >= rand5):
                                                picked = 1
                                                print("Offensive rebound by " + data2.loc[rand4, "Name"])
                                                boxScore2.at[rand4, "ORB"] = boxScore2.loc[rand4, "ORB"] + 1
                                                boxScore2.at[rand4, "TRB"] = boxScore2.loc[rand4, "TRB"] + 1

                                    else: #picking defensive rebounder for opposing team
                                        pos = 1
                                        picked = 0 
                                        while picked == 0: #Picking defensive rebounder for the opposing team 
                                            rand4 = random.randint(1,data.shape[0]-1) 
                                            rand5 = random.randint(1,101)
                                            cof4 = 100 *(data.loc[rand4, "DRB"]/Drebound)
                                            if(cof4 >= rand5):
                                                picked = 1
                                                print("Defensive rebound by " + data.loc[rand4, "Name"])
                                                boxScore.at[rand4, "DRB"] = boxScore.loc[rand4, "DRB"] + 1
                                                boxScore.at[rand4, "TRB"] = boxScore.loc[rand4, "TRB"] + 1



                else:
                    picked3 = 0 
                    while picked3 == 0:
                        rand4 = random.randint(1,data2.shape[0]-1) 
                        rand5 = random.randint(1,101)
                        cof4 = 100 *(data2.loc[rand4, "TOV"]/TOVb)
                        if(cof4 >= rand5):
                            picked3 = 1
                            turnovers2 = turnovers2 + 1
                            print("Turnover by " + data2.loc[rand4, "Name"])
                            boxScore2.at[rand4, "TOV"] = boxScore2.loc[rand4, "TOV"] + 1
                            pos = 1


            print("Time left: " + str(time/60) + "------ Score: " + str(score1) + " to " + str(score2))    
            time = time - 15 
            if(time <= 0 and (score1 == score2)):
                time == time + 5


        print(score1)
        print(score2)
        print(boxScore)
        print(boxScore2)

        if(score1 > score2 ):
            team1score = team1score +1 
        else:
            team2score = team2score +1 

            
    if(team1score > team2score ):
        return team1 
        
    else:
        return team2

# %%
bracket = pandas.read_csv("bracket.csv")

count = 0 
fillin = [1,9,17,25]
for i in range(0,8,2):
    bracket.at[fillin[count], "First Round"] = game_simulator(bracket.loc[i, "Play in"], bracket.loc[i+1, "Play in"])
    count = count +1 
bracket.to_csv("firstRound3b.csv")
for i in range(0,64,2):
    bracket.at[i/2, "Second Round"] = game_simulator(bracket.loc[i, "First Round"], bracket.loc[i+1, "First Round"])
bracket.to_csv("secondRound3b.csv")
for i in range(0,32,2):
    bracket.at[i/2, "Sweet 16"] = game_simulator(bracket.loc[i, "Second Round"], bracket.loc[i+1, "Second Round"])
bracket.to_csv("sweet163b.csv")
for i in range(0,16,2):
    bracket.at[i/2, "Elite 8"] = game_simulator(bracket.loc[i, "Sweet 16"], bracket.loc[i+1, "Sweet 16"])
for i in range(0,8,2):
    bracket.at[i/2, "Final 4"] = game_simulator(bracket.loc[i, "Elite 8"], bracket.loc[i+1, "Elite 8"])
for i in range(0,4,2):
    bracket.at[i/2, "Championship"] = game_simulator(bracket.loc[i, "Final 4"], bracket.loc[i+1, "Final 4"])
for i in range(0,2,2):
    bracket.at[i/2, "Champions"] = game_simulator(bracket.loc[i, "Championship"], bracket.loc[i+1, "Championship"])

# %%
bracket.to_csv("predictions7.csv")

# %%
winner = []
for i in range(0,99):    
    winner.append(game_simulator("virginia-tech", "liberty"))
print(winner)
# Out:
# 13.617647058823529
# 2PT FG missed by Justin Robinson
# Defensive rebound by Caleb Homesley
# Turnover by Myo Baxter-Bell
# Time left: 39.75------ Score: 0 to 0
# 13.617647058823529
# 2PT FG missed by Kerry Blackshear Jr.
# Defensive rebound by Caleb Homesley
# 3PT FG missed by Caleb Homesley
# Defensive rebound by Ty Outlaw
# Time left: 39.25------ Score: 0 to 0
# 13.617647058823529
# 2PT FG missed by Ahmed Hill
# Offensive rebound by Nickeil Alexander-Walker
# Time left: 38.75------ Score: 0 to 0
# 13.617647058823529
# 2PT FG by P.J. Horne
# 3PT FG missed by Lovell Cabbil
# Defensive rebound by P.J. Horne
# Time left: 38.25------ Score: 2 to 0
# 13.617647058823529
# 3PT FG missed by Ty Outlaw
# Offensive rebound by P.J. Horne
# Time left: 37.75------ Score: 2 to 0
# 13.617647058823529
# 3PT FG by Ty Outlaw
# 3PT FG by Darius McGhee
# Time left: 37.25------ Score: 5 to 3
# 13.617647058823529
# Turnover by Justin Robinson
# 2PT FG missed by Scottie James
# Defensive rebound by Justin Robinson
# Time left: 36.75------ Score: 5 to 3
# 13.617647058823529
# 3PT FG missed by Wabissa Bede
# Defensive rebound by Scottie James
# 3PT FG by Georgie Pacheco-Ortiz
# Time left: 36.25------ Score: 5 to 6
# 13.617647058823529
# 2PT FG by Justin Robinson
# 3PT FG missed by Darius McGhee
# Defensive rebound by Justin Robinson
# Time left: 35.75------ Score: 7 to 6
# 13.617647058823529
# 2PT FG missed by Kerry Blackshear Jr.
# Defensive rebound by Darius McGhee
# 2PT FG missed by Elijah Cuffee
# Defensive rebound by Ahmed Hill
# Time left: 35.25------ Score: 7 to 6
# 13.617647058823529
# Turnover by Ahmed Hill
# Turnover by Scottie James
# Time left: 34.75------ Score: 7 to 6
# 13.617647058823529
# 2PT FG by Nickeil Alexander-Walker
# 3PT FG by Darius McGhee
# Time left: 34.25------ Score: 9 to 9
# 13.617647058823529
# 2PT FG missed by Nickeil Alexander-Walker
# Defensive rebound by Scottie James
# 3PT FG by Darius McGhee
# Time left: 33.75------ Score: 9 to 12
# 13.617647058823529
# 2PT FG by Justin Robinson
# 2PT FG missed by Darius McGhee
# Defensive rebound by Justin Robinson
# Time left: 33.25------ Score: 11 to 12
# 13.617647058823529
# 3PT FG missed by Kerry Blackshear Jr.
# Defensive rebound by Scottie James
# 2PT FG missed by Keenan Gumbs
# Defensive rebound by Ty Outlaw
# Time left: 32.75------ Score: 11 to 12
# 13.617647058823529
# 3PT FG missed by Nickeil Alexander-Walker
# Defensive rebound by Elijah Cuffee
# 3PT FG missed by Myo Baxter-Bell
# Defensive rebound by Wabissa Bede
# Time left: 32.25------ Score: 11 to 12
# 13.617647058823529
# 2PT FG by Justin Robinson
# 3PT FG missed by Keenan Gumbs
# Offensive rebound by Brendan Newton
# Time left: 31.75------ Score: 13 to 12
# 3PT FG by Caleb Homesley
# Time left: 31.25------ Score: 13 to 15
# 13.617647058823529
# 3PT FG missed by Ty Outlaw
# Offensive rebound by Justin Robinson
# Time left: 30.75------ Score: 13 to 15
# 13.617647058823529
# 2PT FG missed by Kerry Blackshear Jr.
# Defensive rebound by Scottie James
# 2PT FG missed by Georgie Pacheco-Ortiz
# Defensive rebound by Kerry Blackshear Jr.
# Time left: 30.25------ Score: 13 to 15
# 13.617647058823529
# 2PT FG by P.J. Horne
# Turnover by Lovell Cabbil
# Time left: 29.75------ Score: 15 to 15
# 13.617647058823529
# 2PT FG missed by Nickeil Alexander-Walker
# Defensive rebound by Caleb Homesley
# 3PT FG by Lovell Cabbil
# Time left: 29.25------ Score: 15 to 18
# 13.617647058823529
# 2PT FG missed by Nickeil Alexander-Walker
# Offensive rebound by Kerry Blackshear Jr.
# Time left: 28.75------ Score: 15 to 18
# 13.617647058823529
# 2PT FG missed by Nickeil Alexander-Walker
# Defensive rebound by Darius McGhee
# Turnover by Caleb Homesley
# Time left: 28.25------ Score: 15 to 18
# 13.617647058823529
# 2PT FG missed by Nickeil Alexander-Walker
# Defensive rebound by Darius McGhee
# 3PT FG missed by Caleb Homesley
# Defensive rebound by Ty Outlaw
# Time left: 27.75------ Score: 15 to 18
# 13.617647058823529
# Turnover by Kerry Blackshear Jr.
# 2PT FG missed by Elijah Cuffee
# Defensive rebound by Ty Outlaw
# Time left: 27.25------ Score: 15 to 18
# 13.617647058823529
# Turnover by Nickeil Alexander-Walker
# Turnover by Caleb Homesley
# Time left: 26.75------ Score: 15 to 18
# 13.617647058823529
# 2PT FG missed by Kerry Blackshear Jr.
# Defensive rebound by Darius McGhee
# 2PT FG missed by Elijah Cuffee
# Offensive rebound by Scottie James
# Time left: 26.25------ Score: 15 to 18
# 2PT FG missed by Caleb Homesley
# Defensive rebound by Isaiah Wilkins
# Time left: 25.75------ Score: 15 to 18
# 13.617647058823529
# Turnover by Justin Robinson
# 3PT FG missed by Keenan Gumbs
# Offensive rebound by Scottie James
# Time left: 25.25------ Score: 15 to 18
# Turnover by Georgie Pacheco-Ortiz
# Time left: 24.75------ Score: 15 to 18
# 13.617647058823529
# Turnover by Wabissa Bede
# 3PT FG by Darius McGhee
# Time left: 24.25------ Score: 15 to 21
# 13.617647058823529
# 2PT FG by Kerry Blackshear Jr.
# Turnover by Lovell Cabbil
# Time left: 23.75------ Score: 17 to 21
# 13.617647058823529
# 2PT FG missed by Justin Robinson
# Defensive rebound by Caleb Homesley
# 2PT FG by Scottie James
# Time left: 23.25------ Score: 17 to 23
# 13.617647058823529
# Turnover by Wabissa Bede
# 2PT FG missed by Caleb Homesley
# Defensive rebound by Wabissa Bede
# Time left: 22.75------ Score: 17 to 23
# 13.617647058823529
# 2PT FG missed by Kerry Blackshear Jr.
# Defensive rebound by Caleb Homesley
# Turnover by Elijah Cuffee
# Time left: 22.25------ Score: 17 to 23
# 13.617647058823529
# 3PT FG missed by Isaiah Wilkins
# Defensive rebound by Scottie James
# 3PT FG missed by Darius McGhee
# Defensive rebound by Ty Outlaw
# Time left: 21.75------ Score: 17 to 23
# 13.617647058823529
# 3PT FG by Ty Outlaw
# 2PT FG missed by Georgie Pacheco-Ortiz
# Defensive rebound by P.J. Horne
# Time left: 21.25------ Score: 20 to 23
# 13.617647058823529
# 3PT FG by Wabissa Bede
# 3PT FG missed by Caleb Homesley
# Defensive rebound by Ty Outlaw
# Time left: 20.75------ Score: 23 to 23
# 13.617647058823529
# 2PT FG by Ahmed Hill
# 2PT FG by Caleb Homesley
# Time left: 20.25------ Score: 25 to 25
# 13.617647058823529
# 2PT FG missed by Nickeil Alexander-Walker
# Offensive rebound by Justin Robinson
# Time left: 19.75------ Score: 25 to 25
# 13.617647058823529
# 2PT FG missed by Kerry Blackshear Jr.
# Defensive rebound by Elijah Cuffee
# 3PT FG missed by Elijah Cuffee
# Defensive rebound by Ahmed Hill
# Time left: 19.25------ Score: 25 to 25
# 13.617647058823529
# 3PT FG by Nickeil Alexander-Walker
# 2PT FG by Keenan Gumbs
# Time left: 18.75------ Score: 28 to 27
# 13.617647058823529
# Turnover by Ahmed Hill
# Turnover by Myo Baxter-Bell
# Time left: 18.25------ Score: 28 to 27
# 13.617647058823529
# Turnover by Kerry Blackshear Jr.
# 2PT FG missed by Georgie Pacheco-Ortiz
# Defensive rebound by Nickeil Alexander-Walker
# Time left: 17.75------ Score: 28 to 27
# 13.617647058823529
# 2PT FG missed by Justin Robinson
# Defensive rebound by Caleb Homesley
# 3PT FG missed by Darius McGhee
# Defensive rebound by Isaiah Wilkins
# Time left: 17.25------ Score: 28 to 27
# 13.617647058823529
# 2PT FG missed by Ahmed Hill
# Defensive rebound by Caleb Homesley
# 3PT FG by Darius McGhee
# Time left: 16.75------ Score: 28 to 30
# 13.617647058823529
# 3PT FG missed by Wabissa Bede
# Defensive rebound by Lovell Cabbil
# 3PT FG by Caleb Homesley
# Time left: 16.25------ Score: 28 to 33
# 13.617647058823529
# 2PT FG by P.J. Horne
# 2PT FG by Caleb Homesley
# Time left: 15.75------ Score: 30 to 35
# 13.617647058823529
# 2PT FG missed by Kerry Blackshear Jr.
# Offensive rebound by Ty Outlaw
# Time left: 15.25------ Score: 30 to 35
# 13.617647058823529
# 2PT FG missed by Wabissa Bede
# Offensive rebound by Kerry Blackshear Jr.
# Time left: 14.75------ Score: 30 to 35
# 13.617647058823529
# 3PT FG missed by Nickeil Alexander-Walker
# Defensive rebound by Caleb Homesley
# 2PT FG missed by Myo Baxter-Bell
# Defensive rebound by Nickeil Alexander-Walker
# Time left: 14.25------ Score: 30 to 35
# 13.617647058823529
# 3PT FG missed by Nickeil Alexander-Walker
# Defensive rebound by Keegan McDowell
# 2PT FG missed by Caleb Homesley
# Defensive rebound by Wabissa Bede
# Time left: 13.75------ Score: 30 to 35
# 13.617647058823529
# 3PT FG missed by Ahmed Hill
# Offensive rebound by Kerry Blackshear Jr.
# Time left: 13.25------ Score: 30 to 35
# 13.617647058823529
# 2PT FG missed by Ty Outlaw
# Defensive rebound by Keenan Gumbs
# 3PT FG missed by Caleb Homesley
# Offensive rebound by Lovell Cabbil
# Time left: 12.75------ Score: 30 to 35
# 2PT FG by Lovell Cabbil
# Time left: 12.25------ Score: 30 to 37
# 13.617647058823529
# 2PT FG by P.J. Horne
# 3PT FG missed by Caleb Homesley
# Defensive rebound by Justin Robinson
# Time left: 11.75------ Score: 32 to 37
# 13.617647058823529
# 2PT FG by Ahmed Hill
# 3PT FG missed by Keenan Gumbs
# Offensive rebound by Scottie James
# Time left: 11.25------ Score: 34 to 37
# Turnover by Georgie Pacheco-Ortiz
# Time left: 10.75------ Score: 34 to 37
# 13.617647058823529
# Turnover by Kerry Blackshear Jr.
# 3PT FG missed by Elijah Cuffee
# Offensive rebound by Keenan Gumbs
# Time left: 10.25------ Score: 34 to 37
# Turnover by Caleb Homesley
# Time left: 9.75------ Score: 34 to 37
# 13.617647058823529
# Turnover by Isaiah Wilkins
# 2PT FG missed by Keenan Gumbs
# Defensive rebound by Nickeil Alexander-Walker
# Time left: 9.25------ Score: 34 to 37
# 13.617647058823529
# Turnover by Ahmed Hill
# 3PT FG missed by Lovell Cabbil
# Defensive rebound by Ty Outlaw
# Time left: 8.75------ Score: 34 to 37
# 13.617647058823529
# 3PT FG by Isaiah Wilkins
# 2PT FG missed by Georgie Pacheco-Ortiz
# Defensive rebound by Isaiah Wilkins
# Time left: 8.25------ Score: 37 to 37
# 13.617647058823529
# 3PT FG by Jonathan Kabongo
# 2PT FG missed by Scottie James
# Defensive rebound by Ty Outlaw
# Time left: 7.75------ Score: 40 to 37
# 13.617647058823529
# 3PT FG missed by Wabissa Bede
# Defensive rebound by Caleb Homesley
# 3PT FG missed by Darius McGhee
# Defensive rebound by Ty Outlaw
# Time left: 7.25------ Score: 40 to 37
# 13.617647058823529
# 2PT FG by Kerry Blackshear Jr.
# Turnover by Elijah Cuffee
# Time left: 6.75------ Score: 42 to 37
# 13.617647058823529
# 2PT FG by Nickeil Alexander-Walker
# 2PT FG by Keenan Gumbs
# Time left: 6.25------ Score: 44 to 39
# 13.617647058823529
# 3PT FG by Justin Robinson
# 2PT FG missed by Georgie Pacheco-Ortiz
# Defensive rebound by Nickeil Alexander-Walker
# Time left: 5.75------ Score: 47 to 39
# 13.617647058823529
# 2PT FG missed by Ty Outlaw
# Defensive rebound by Caleb Homesley
# Turnover by Myo Baxter-Bell
# Time left: 5.25------ Score: 47 to 39
# 13.617647058823529
# 2PT FG by Nickeil Alexander-Walker
# 2PT FG by Caleb Homesley
# Time left: 4.75------ Score: 49 to 41
# 13.617647058823529
# Turnover by Justin Robinson
# 3PT FG missed by Darius McGhee
# Offensive rebound by Elijah Cuffee
# Time left: 4.25------ Score: 49 to 41
# 2PT FG missed by Myo Baxter-Bell
# Defensive rebound by Wabissa Bede
# Time left: 3.75------ Score: 49 to 41
# 13.617647058823529
# 2PT FG by Kerry Blackshear Jr.
# 3PT FG by Lovell Cabbil
# Time left: 3.25------ Score: 51 to 44
# 13.617647058823529
# 2PT FG by Justin Robinson
# 3PT FG missed by Elijah Cuffee
# Defensive rebound by Jonathan Kabongo
# Time left: 2.75------ Score: 53 to 44
# 13.617647058823529
# 3PT FG missed by Ahmed Hill
# Defensive rebound by Caleb Homesley
# 3PT FG missed by Keenan Gumbs
# Defensive rebound by Nickeil Alexander-Walker
# Time left: 2.25------ Score: 53 to 44
# 13.617647058823529
# Turnover by Justin Robinson
# 3PT FG missed by Darius McGhee
# Defensive rebound by Kerry Blackshear Jr.
# Time left: 1.75------ Score: 53 to 44
# 13.617647058823529
# Turnover by Nickeil Alexander-Walker
# Turnover by Caleb Homesley
# Time left: 1.25------ Score: 53 to 44
# 13.617647058823529
# 2PT FG missed by Ahmed Hill
# Defensive rebound by Caleb Homesley
# Turnover by Keenan Gumbs
# Time left: 0.75------ Score: 53 to 44
# 13.617647058823529
# 2PT FG by Justin Robinson
# Turnover by Elijah Cuffee
# Time left: 0.25------ Score: 55 to 44
# 55
# 44
#                         Name  Points  2PM  2PA  3PM  3PA  TOV  ORB  DRB  TRB
# 1   Nickeil Alexander-Walker       9    3    9    1    4    2    1    5    6
# 2       Kerry Blackshear Jr.       6    3   10    0    1    3    3    2    5
# 3            Justin Robinson      13    5    8    1    1    4    2    4    6
# 4                 Ahmed Hill       4    2    5    0    2    3    0    2    2
# 5                  Ty Outlaw       6    0    2    2    4    0    1    9   10
# 6             Isaiah Wilkins       3    0    0    1    2    1    0    3    3
# 7                 P.J. Horne       8    4    4    0    0    0    1    2    3
# 8               Wabissa Bede       3    0    1    1    4    2    0    4    4
# 9           Jonathan Kabongo       3    0    0    1    1    0    0    1    1
# 10            Brendan Palmer       0    0    0    0    0    0    0    0    0
#                      Name  Points  2PM  2PA  3PM  3PA  TOV  ORB  DRB  TRB
# 1           Scottie James       2    1    3    0    0    1    3    5    8
# 2          Caleb Homesley      12    3    6    2    7    4    0   12   12
# 3           Lovell Cabbil       8    1    1    2    4    2    1    1    2
# 4           Elijah Cuffee       0    0    3    0    3    3    1    2    3
# 5           Darius McGhee      15    0    1    5   11    0    0    4    4
# 6   Georgie Pacheco-Ortiz       3    0    5    1    1    2    0    0    0
# 7            Keenan Gumbs       4    2    4    0    4    1    1    1    2
# 8         Myo Baxter-Bell       0    0    2    0    1    3    0    0    0
# 9         Keegan McDowell       0    0    0    0    0    0    0    1    1
# 10         Brendan Newton       0    0    0    0    0    0    1    0    1
# 11          Zach Farquhar       0    0    0    0    0    0    0    0    0
# 13.617647058823529
# Turnover by Wabissa Bede
# 3PT FG missed by Lovell Cabbil
# Defensive rebound by Wabissa Bede
# Time left: 39.75------ Score: 0 to 0
# 13.617647058823529
# 2PT FG by Kerry Blackshear Jr.
# 2PT FG missed by Lovell Cabbil
# Offensive rebound by Elijah Cuffee
# Time left: 39.25------ Score: 2 to 0
# 3PT FG missed by Georgie Pacheco-Ortiz
# Defensive rebound by Ahmed Hill
# Time left: 38.75------ Score: 2 to 0
# 13.617647058823529
# Turnover by Justin Robinson
# Turnover by Elijah Cuffee
# Time left: 38.25------ Score: 2 to 0
# 13.617647058823529
# 3PT FG by Ahmed Hill
# 2PT FG missed by Georgie Pacheco-Ortiz
# Offensive rebound by Georgie Pacheco-Ortiz
# Time left: 37.75------ Score: 5 to 0
# 3PT FG by Lovell Cabbil
# Time left: 37.25------ Score: 5 to 3
# 13.617647058823529
# 2PT FG missed by Nickeil Alexander-Walker
# Defensive rebound by Scottie James
# 2PT FG by Scottie James
# Time left: 36.75------ Score: 5 to 5
# 13.617647058823529
# 3PT FG missed by Ahmed Hill
# Defensive rebound by Keenan Gumbs
# 2PT FG by Caleb Homesley
# Time left: 36.25------ Score: 5 to 7
# 13.617647058823529
# 2PT FG by Nickeil Alexander-Walker
# 3PT FG missed by Keegan McDowell
# Offensive rebound by Georgie Pacheco-Ortiz
# Time left: 35.75------ Score: 7 to 7
# 3PT FG by Keegan McDowell
# Time left: 35.25------ Score: 7 to 10
# 13.617647058823529
# 3PT FG missed by Kerry Blackshear Jr.
# Defensive rebound by Darius McGhee
# 3PT FG by Georgie Pacheco-Ortiz
# Time left: 34.75------ Score: 7 to 13
# 13.617647058823529
# 3PT FG by Justin Robinson
# 3PT FG missed by Keenan Gumbs
# Defensive rebound by Justin Robinson
# Time left: 34.25------ Score: 10 to 13
# 13.617647058823529
# 2PT FG by Justin Robinson
# 2PT FG missed by Caleb Homesley
# Defensive rebound by Nickeil Alexander-Walker
# Time left: 33.75------ Score: 12 to 13
# 13.617647058823529
# Turnover by P.J. Horne
# Turnover by Lovell Cabbil
# Time left: 33.25------ Score: 12 to 13
# 13.617647058823529
# 2PT FG missed by Isaiah Wilkins
# Defensive rebound by Darius McGhee
# Turnover by Caleb Homesley
# Time left: 32.75------ Score: 12 to 13
# 13.617647058823529
# 2PT FG by Kerry Blackshear Jr.
# 3PT FG by Elijah Cuffee
# Time left: 32.25------ Score: 14 to 16
# 13.617647058823529
# Turnover by Kerry Blackshear Jr.
# Turnover by Lovell Cabbil
# Time left: 31.75------ Score: 14 to 16
# 13.617647058823529
# 2PT FG missed by P.J. Horne
# Offensive rebound by Justin Robinson
# Time left: 31.25------ Score: 14 to 16
# 13.617647058823529
# 2PT FG by Nickeil Alexander-Walker
# 2PT FG missed by Georgie Pacheco-Ortiz
# Defensive rebound by Ty Outlaw
# Time left: 30.75------ Score: 16 to 16
# 13.617647058823529
# 3PT FG missed by Justin Robinson
# Defensive rebound by Caleb Homesley
# 3PT FG missed by Caleb Homesley
# Defensive rebound by Kerry Blackshear Jr.
# Time left: 30.25------ Score: 16 to 16
# 13.617647058823529
# 3PT FG missed by Kerry Blackshear Jr.
# Defensive rebound by Georgie Pacheco-Ortiz
# 3PT FG missed by Lovell Cabbil
# Defensive rebound by Nickeil Alexander-Walker
# Time left: 29.75------ Score: 16 to 16
# 13.617647058823529
# 2PT FG by Justin Robinson
# 2PT FG missed by Caleb Homesley
# Defensive rebound by Isaiah Wilkins
# Time left: 29.25------ Score: 18 to 16
# 13.617647058823529
# 2PT FG missed by Nickeil Alexander-Walker
# Defensive rebound by Keenan Gumbs
# 2PT FG missed by Caleb Homesley
# Offensive rebound by Scottie James
# Time left: 28.75------ Score: 18 to 16
# Turnover by Myo Baxter-Bell
# Time left: 28.25------ Score: 18 to 16
# 13.617647058823529
# 2PT FG missed by Ahmed Hill
# Offensive rebound by Ahmed Hill
# Time left: 27.75------ Score: 18 to 16
# 13.617647058823529
# 3PT FG missed by Ty Outlaw
# Offensive rebound by Nickeil Alexander-Walker
# Time left: 27.25------ Score: 18 to 16
# 13.617647058823529
# 2PT FG missed by Justin Robinson
# Defensive rebound by Scottie James
# 3PT FG missed by Darius McGhee
# Defensive rebound by Ty Outlaw
# Time left: 26.75------ Score: 18 to 16
# 13.617647058823529
# Turnover by Isaiah Wilkins
# 2PT FG by Keenan Gumbs
# Time left: 26.25------ Score: 18 to 18
# 13.617647058823529
# 2PT FG by Nickeil Alexander-Walker
# 2PT FG missed by Caleb Homesley
# Defensive rebound by Nickeil Alexander-Walker
# Time left: 25.75------ Score: 20 to 18
# 13.617647058823529
# 2PT FG missed by Nickeil Alexander-Walker
# Offensive rebound by Kerry Blackshear Jr.
# Time left: 25.25------ Score: 20 to 18
# 13.617647058823529
# 2PT FG by Kerry Blackshear Jr.
# 3PT FG by Lovell Cabbil
# Time left: 24.75------ Score: 22 to 21
# 13.617647058823529
# 3PT FG missed by Ty Outlaw
# Defensive rebound by Lovell Cabbil
# 3PT FG missed by Georgie Pacheco-Ortiz
# Defensive rebound by Kerry Blackshear Jr.
# Time left: 24.25------ Score: 22 to 21
# 13.617647058823529
# 2PT FG by P.J. Horne
# 2PT FG missed by Georgie Pacheco-Ortiz
# Offensive rebound by Scottie James
# Time left: 23.75------ Score: 24 to 21
# 3PT FG missed by Georgie Pacheco-Ortiz
# Defensive rebound by Kerry Blackshear Jr.
# Time left: 23.25------ Score: 24 to 21
# 13.617647058823529
# 3PT FG missed by Wabissa Bede
# Offensive rebound by Kerry Blackshear Jr.
# Time left: 22.75------ Score: 24 to 21
# 13.617647058823529
# Turnover by Isaiah Wilkins
# 2PT FG missed by Caleb Homesley
# Defensive rebound by Kerry Blackshear Jr.
# Time left: 22.25------ Score: 24 to 21
# 13.617647058823529
# 2PT FG by Nickeil Alexander-Walker
# 3PT FG missed by Lovell Cabbil
# Defensive rebound by Wabissa Bede
# Time left: 21.75------ Score: 26 to 21
# 13.617647058823529
# 2PT FG by Kerry Blackshear Jr.
# 3PT FG missed by Scottie James
# Defensive rebound by Nickeil Alexander-Walker
# Time left: 21.25------ Score: 28 to 21
# 13.617647058823529
# Turnover by Nickeil Alexander-Walker
# 2PT FG missed by Myo Baxter-Bell
# Offensive rebound by Brendan Newton
# Time left: 20.75------ Score: 28 to 21
# 3PT FG missed by Georgie Pacheco-Ortiz
# Defensive rebound by Wabissa Bede
# Time left: 20.25------ Score: 28 to 21
# 13.617647058823529
# Turnover by Isaiah Wilkins
# 2PT FG missed by Caleb Homesley
# Offensive rebound by Myo Baxter-Bell
# Time left: 19.75------ Score: 28 to 21
# Turnover by Scottie James
# Time left: 19.25------ Score: 28 to 21
# 13.617647058823529
# 3PT FG missed by Nickeil Alexander-Walker
# Defensive rebound by Myo Baxter-Bell
# 2PT FG by Caleb Homesley
# Time left: 18.75------ Score: 28 to 23
# 13.617647058823529
# 2PT FG by P.J. Horne
# 2PT FG by Scottie James
# Time left: 18.25------ Score: 30 to 25
# 13.617647058823529
# 2PT FG by Nickeil Alexander-Walker
# Turnover by Scottie James
# Time left: 17.75------ Score: 32 to 25
# 13.617647058823529
# Turnover by Ahmed Hill
# 2PT FG missed by Lovell Cabbil
# Offensive rebound by Keegan McDowell
# Time left: 17.25------ Score: 32 to 25
# Turnover by Keegan McDowell
# Time left: 16.75------ Score: 32 to 25
# 13.617647058823529
# 2PT FG missed by Justin Robinson
# Offensive rebound by Kerry Blackshear Jr.
# Time left: 16.25------ Score: 32 to 25
# 13.617647058823529
# 2PT FG missed by Justin Robinson
# Defensive rebound by Caleb Homesley
# 3PT FG missed by Darius McGhee
# Defensive rebound by Justin Robinson
# Time left: 15.75------ Score: 32 to 25
# 13.617647058823529
# Turnover by Justin Robinson
# 2PT FG missed by Scottie James
# Defensive rebound by Ahmed Hill
# Time left: 15.25------ Score: 32 to 25
# 13.617647058823529
# 3PT FG by Ty Outlaw
# 2PT FG missed by Caleb Homesley
# Defensive rebound by Nickeil Alexander-Walker
# Time left: 14.75------ Score: 35 to 25
# 13.617647058823529
# 2PT FG by Kerry Blackshear Jr.
# 2PT FG by Caleb Homesley
# Time left: 14.25------ Score: 37 to 27
# 13.617647058823529
# 2PT FG by Nickeil Alexander-Walker
# 3PT FG by Georgie Pacheco-Ortiz
# Time left: 13.75------ Score: 39 to 30
# 13.617647058823529
# 2PT FG by Nickeil Alexander-Walker
# Turnover by Elijah Cuffee
# Time left: 13.25------ Score: 41 to 30
# 13.617647058823529
# Turnover by Nickeil Alexander-Walker
# 2PT FG missed by Georgie Pacheco-Ortiz
# Offensive rebound by Scottie James
# Time left: 12.75------ Score: 41 to 30
# 2PT FG missed by Elijah Cuffee
# Defensive rebound by Ty Outlaw
# Time left: 12.25------ Score: 41 to 30
# 13.617647058823529
# 2PT FG by Justin Robinson
# 2PT FG missed by Caleb Homesley
# Defensive rebound by Ty Outlaw
# Time left: 11.75------ Score: 43 to 30
# 13.617647058823529
# 3PT FG missed by Isaiah Wilkins
# Offensive rebound by Wabissa Bede
# Time left: 11.25------ Score: 43 to 30
# 13.617647058823529
# 2PT FG by Wabissa Bede
# 3PT FG by Georgie Pacheco-Ortiz
# Time left: 10.75------ Score: 45 to 33
# 13.617647058823529
# 3PT FG by Ahmed Hill
# 2PT FG by Myo Baxter-Bell
# Time left: 10.25------ Score: 48 to 35
# 13.617647058823529
# 2PT FG missed by Kerry Blackshear Jr.
# Defensive rebound by Scottie James
# 2PT FG by Lovell Cabbil
# Time left: 9.75------ Score: 48 to 37
# 13.617647058823529
# 2PT FG missed by Kerry Blackshear Jr.
# Defensive rebound by Caleb Homesley
# 3PT FG missed by Lovell Cabbil
# Defensive rebound by Kerry Blackshear Jr.
# Time left: 9.25------ Score: 48 to 37
# 13.617647058823529
# 2PT FG by Nickeil Alexander-Walker
# Turnover by Lovell Cabbil
# Time left: 8.75------ Score: 50 to 37
# 13.617647058823529
# 2PT FG missed by P.J. Horne
# Defensive rebound by Caleb Homesley
# 3PT FG missed by Georgie Pacheco-Ortiz
# Defensive rebound by Ahmed Hill
# Time left: 8.25------ Score: 50 to 37
# 13.617647058823529
# 2PT FG missed by Nickeil Alexander-Walker
# Defensive rebound by Caleb Homesley
# 3PT FG missed by Lovell Cabbil
# Defensive rebound by Justin Robinson
# Time left: 7.75------ Score: 50 to 37
# 13.617647058823529
# 2PT FG missed by Kerry Blackshear Jr.
# Offensive rebound by Kerry Blackshear Jr.
# Time left: 7.25------ Score: 50 to 37
# 13.617647058823529
# 3PT FG missed by Kerry Blackshear Jr.
# Offensive rebound by Isaiah Wilkins
# Time left: 6.75------ Score: 50 to 37
# 13.617647058823529
# 2PT FG missed by Ahmed Hill
# Defensive rebound by Keenan Gumbs
# 2PT FG by Lovell Cabbil
# Time left: 6.25------ Score: 50 to 39
# 13.617647058823529
# 3PT FG by Ty Outlaw
# 2PT FG by Elijah Cuffee
# Time left: 5.75------ Score: 53 to 41
# 13.617647058823529
# 3PT FG missed by Ahmed Hill
# Defensive rebound by Scottie James
# 3PT FG missed by Darius McGhee
# Defensive rebound by Kerry Blackshear Jr.
# Time left: 5.25------ Score: 53 to 41
# 13.617647058823529
# 2PT FG by Kerry Blackshear Jr.
# Turnover by Scottie James
# Time left: 4.75------ Score: 55 to 41
# 13.617647058823529
# 2PT FG missed by Nickeil Alexander-Walker
# Offensive rebound by Kerry Blackshear Jr.
# Time left: 4.25------ Score: 55 to 41
# 13.617647058823529
# 2PT FG by Ahmed Hill
# 2PT FG by Myo Baxter-Bell
# Time left: 3.75------ Score: 57 to 43
# 13.617647058823529
# 3PT FG missed by Nickeil Alexander-Walker
# Defensive rebound by Scottie James
# Turnover by Elijah Cuffee
# Time left: 3.25------ Score: 57 to 43
# 13.617647058823529
# 3PT FG by Justin Robinson
# 3PT FG missed by Keegan McDowell
# Defensive rebound by P.J. Horne
# Time left: 2.75------ Score: 60 to 43
# 13.617647058823529
# 2PT FG by Kerry Blackshear Jr.
# 3PT FG missed by Darius McGhee
# Offensive rebound by Brendan Newton
# Time left: 2.25------ Score: 62 to 43
# Turnover by Caleb Homesley
# Time left: 1.75------ Score: 62 to 43
# 13.617647058823529
# Turnover by Nickeil Alexander-Walker
# Turnover by Myo Baxter-Bell
# Time left: 1.25------ Score: 62 to 43
# 13.617647058823529
# 3PT FG missed by Nickeil Alexander-Walker
# Defensive rebound by Caleb Homesley
# 3PT FG by Elijah Cuffee
# Time left: 0.75------ Score: 62 to 46
# 13.617647058823529
# Turnover by P.J. Horne
# 2PT FG missed by Lovell Cabbil
# Defensive rebound by Ahmed Hill
# Time left: 0.25------ Score: 62 to 46
# 62
# 46
#                         Name  Points  2PM  2PA  3PM  3PA  TOV  ORB  DRB  TRB
# 1   Nickeil Alexander-Walker      16    8   13    0    3    3    1    5    6
# 2       Kerry Blackshear Jr.      14    7   10    0    3    1    5    6   11
# 3            Justin Robinson      12    3    6    2    3    2    1    3    4
# 4                 Ahmed Hill       8    1    3    2    4    1    1    4    5
# 5                  Ty Outlaw       6    0    0    2    4    0    0    4    4
# 6             Isaiah Wilkins       0    0    1    0    1    3    1    1    2
# 7                 P.J. Horne       4    2    4    0    0    2    0    1    1
# 8               Wabissa Bede       2    1    1    0    1    1    1    3    4
# 9           Jonathan Kabongo       0    0    0    0    0    0    0    0    0
# 10            Brendan Palmer       0    0    0    0    0    0    0    0    0
#                      Name  Points  2PM  2PA  3PM  3PA  TOV  ORB  DRB  TRB
# 1           Scottie James       4    2    3    0    1    3    3    5    8
# 2          Caleb Homesley       6    3   11    0    1    2    0    6    6
# 3           Lovell Cabbil      10    2    5    2    7    3    0    1    1
# 4           Elijah Cuffee       8    1    2    2    2    3    1    0    1
# 5           Darius McGhee       0    0    0    0    4    0    0    2    2
# 6   Georgie Pacheco-Ortiz       9    0    4    3    8    0    2    1    3
# 7            Keenan Gumbs       2    1    1    0    1    0    0    3    3
# 8         Myo Baxter-Bell       4    2    3    0    0    2    1    1    2
# 9         Keegan McDowell       3    0    0    1    3    1    1    0    1
# 10         Brendan Newton       0    0    0    0    0    0    2    0    2
# 11          Zach Farquhar       0    0    0    0    0    0    0    0    0
# 13.617647058823529
# 3PT FG missed by Kerry Blackshear Jr.
# Defensive rebound by Scottie James
# 2PT FG missed by Myo Baxter-Bell
# Defensive rebound by Nickeil Alexander-Walker
# Time left: 39.75------ Score: 0 to 0
# 13.617647058823529
# 2PT FG missed by P.J. Horne
# Defensive rebound by Keenan Gumbs
# 2PT FG missed by Scottie James
# Defensive rebound by Ty Outlaw
# Time left: 39.25------ Score: 0 to 0
# 13.617647058823529
# 2PT FG missed by Justin Robinson
# Offensive rebound by Kerry Blackshear Jr.
# Time left: 38.75------ Score: 0 to 0
# 13.617647058823529
# 3PT FG missed by Isaiah Wilkins
# Defensive rebound by Caleb Homesley
# Turnover by Keenan Gumbs
# Time left: 38.25------ Score: 0 to 0
# 13.617647058823529
# 2PT FG missed by Kerry Blackshear Jr.
# Offensive rebound by P.J. Horne
# Time left: 37.75------ Score: 0 to 0
# 13.617647058823529
# Turnover by Isaiah Wilkins
# 3PT FG missed by Scottie James
# Defensive rebound by Ty Outlaw
# Time left: 37.25------ Score: 0 to 0
# 13.617647058823529
# 2PT FG missed by Ahmed Hill
# Offensive rebound by P.J. Horne
# Time left: 36.75------ Score: 0 to 0
# 13.617647058823529
# Turnover by Nickeil Alexander-Walker
# 3PT FG missed by Darius McGhee
# Defensive rebound by Ahmed Hill
# Time left: 36.25------ Score: 0 to 0
# 13.617647058823529
# 2PT FG by Kerry Blackshear Jr.
# 2PT FG by Myo Baxter-Bell
# Time left: 35.75------ Score: 2 to 2
# 13.617647058823529
# 3PT FG missed by Kerry Blackshear Jr.
# Offensive rebound by Wabissa Bede
# Time left: 35.25------ Score: 2 to 2
# 13.617647058823529
# 2PT FG by Kerry Blackshear Jr.
# Turnover by Keegan McDowell
# Time left: 34.75------ Score: 4 to 2
# 13.617647058823529
# Turnover by Nickeil Alexander-Walker
# Turnover by Caleb Homesley
# Time left: 34.25------ Score: 4 to 2
# 13.617647058823529
# 2PT FG by Kerry Blackshear Jr.
# 2PT FG missed by Lovell Cabbil
# Offensive rebound by Scottie James
# Time left: 33.75------ Score: 6 to 2
# Turnover by Georgie Pacheco-Ortiz
# Time left: 33.25------ Score: 6 to 2
# 13.617647058823529
# 2PT FG by Wabissa Bede
# 2PT FG by Scottie James
# Time left: 32.75------ Score: 8 to 4
# 13.617647058823529
# 3PT FG missed by Kerry Blackshear Jr.
# Defensive rebound by Darius McGhee
# Turnover by Scottie James
# Time left: 32.25------ Score: 8 to 4
# 13.617647058823529
# 2PT FG missed by Kerry Blackshear Jr.
# Defensive rebound by Scottie James
# 3PT FG missed by Scottie James
# Defensive rebound by Ahmed Hill
# Time left: 31.75------ Score: 8 to 4
# 13.617647058823529
# 2PT FG missed by Isaiah Wilkins
# Defensive rebound by Darius McGhee
# 3PT FG by Lovell Cabbil
# Time left: 31.25------ Score: 8 to 7
# 13.617647058823529
# 2PT FG missed by Nickeil Alexander-Walker
# Defensive rebound by Darius McGhee
# 3PT FG by Elijah Cuffee
# Time left: 30.75------ Score: 8 to 10
# 13.617647058823529
# 2PT FG by Nickeil Alexander-Walker
# Turnover by Myo Baxter-Bell
# Time left: 30.25------ Score: 10 to 10
# 13.617647058823529
# 2PT FG by Nickeil Alexander-Walker
# 2PT FG missed by Lovell Cabbil
# Defensive rebound by Ty Outlaw
# Time left: 29.75------ Score: 12 to 10
# 13.617647058823529
# 3PT FG missed by Isaiah Wilkins
# Defensive rebound by Keegan McDowell
# 2PT FG missed by Keenan Gumbs
# Defensive rebound by Kerry Blackshear Jr.
# Time left: 29.25------ Score: 12 to 10
# 13.617647058823529
# 3PT FG by Ahmed Hill
# 2PT FG missed by Scottie James
# Defensive rebound by Kerry Blackshear Jr.
# Time left: 28.75------ Score: 15 to 10
# 13.617647058823529
# 2PT FG missed by Justin Robinson
# Defensive rebound by Darius McGhee
# Turnover by Myo Baxter-Bell
# Time left: 28.25------ Score: 15 to 10
# 13.617647058823529
# Turnover by Nickeil Alexander-Walker
# Turnover by Darius McGhee
# Time left: 27.75------ Score: 15 to 10
# 13.617647058823529
# 2PT FG missed by Nickeil Alexander-Walker
# Offensive rebound by Nickeil Alexander-Walker
# Time left: 27.25------ Score: 15 to 10
# 13.617647058823529
# Turnover by Nickeil Alexander-Walker
# 3PT FG missed by Darius McGhee
# Defensive rebound by Wabissa Bede
# Time left: 26.75------ Score: 15 to 10
# 13.617647058823529
# 2PT FG missed by Isaiah Wilkins
# Offensive rebound by Kerry Blackshear Jr.
# Time left: 26.25------ Score: 15 to 10
# 13.617647058823529
# 3PT FG by Ahmed Hill
# Turnover by Myo Baxter-Bell
# Time left: 25.75------ Score: 18 to 10
# 13.617647058823529
# 2PT FG by Nickeil Alexander-Walker
# 3PT FG missed by Caleb Homesley
# Defensive rebound by Justin Robinson
# Time left: 25.25------ Score: 20 to 10
# 13.617647058823529
# 3PT FG missed by Wabissa Bede
# Offensive rebound by Kerry Blackshear Jr.
# Time left: 24.75------ Score: 20 to 10
# 13.617647058823529
# 2PT FG missed by Justin Robinson
# Offensive rebound by Justin Robinson
# Time left: 24.25------ Score: 20 to 10
# 13.617647058823529
# Turnover by Nickeil Alexander-Walker
# 3PT FG missed by Darius McGhee
# Defensive rebound by Kerry Blackshear Jr.
# Time left: 23.75------ Score: 20 to 10
# 13.617647058823529
# Turnover by Wabissa Bede
# 3PT FG missed by Lovell Cabbil
# Offensive rebound by Scottie James
# Time left: 23.25------ Score: 20 to 10
# Turnover by Myo Baxter-Bell
# Time left: 22.75------ Score: 20 to 10
# 13.617647058823529
# Turnover by Justin Robinson
# 2PT FG missed by Georgie Pacheco-Ortiz
# Defensive rebound by Ty Outlaw
# Time left: 22.25------ Score: 20 to 10
# 13.617647058823529
# 2PT FG missed by Justin Robinson
# Defensive rebound by Myo Baxter-Bell
# 3PT FG missed by Caleb Homesley
# Defensive rebound by Ahmed Hill
# Time left: 21.75------ Score: 20 to 10
# 13.617647058823529
# 2PT FG by Nickeil Alexander-Walker
# 3PT FG missed by Caleb Homesley
# Offensive rebound by Myo Baxter-Bell
# Time left: 21.25------ Score: 22 to 10
# 3PT FG missed by Georgie Pacheco-Ortiz
# Offensive rebound by Darius McGhee
# Time left: 20.75------ Score: 22 to 10
# 2PT FG missed by Keenan Gumbs
# Defensive rebound by Nickeil Alexander-Walker
# Time left: 20.25------ Score: 22 to 10
# 13.617647058823529
# 2PT FG missed by Isaiah Wilkins
# Defensive rebound by Lovell Cabbil
# 3PT FG by Caleb Homesley
# Time left: 19.75------ Score: 22 to 13
# 13.617647058823529
# 2PT FG missed by Nickeil Alexander-Walker
# Defensive rebound by Scottie James
# 3PT FG by Darius McGhee
# Time left: 19.25------ Score: 22 to 16
# 13.617647058823529
# 2PT FG missed by Wabissa Bede
# Defensive rebound by Georgie Pacheco-Ortiz
# Turnover by Lovell Cabbil
# Time left: 18.75------ Score: 22 to 16
# 13.617647058823529
# 3PT FG by Nickeil Alexander-Walker
# 3PT FG by Darius McGhee
# Time left: 18.25------ Score: 25 to 19
# 13.617647058823529
# 3PT FG missed by Kerry Blackshear Jr.
# Defensive rebound by Caleb Homesley
# 2PT FG missed by Myo Baxter-Bell
# Defensive rebound by Justin Robinson
# Time left: 17.75------ Score: 25 to 19
# 13.617647058823529
# 3PT FG by Kerry Blackshear Jr.
# 2PT FG missed by Scottie James
# Offensive rebound by Keenan Gumbs
# Time left: 17.25------ Score: 28 to 19
# 2PT FG missed by Myo Baxter-Bell
# Offensive rebound by Myo Baxter-Bell
# Time left: 16.75------ Score: 28 to 19
# 2PT FG by Scottie James
# Time left: 16.25------ Score: 28 to 21
# 13.617647058823529
# 2PT FG missed by P.J. Horne
# Offensive rebound by Ahmed Hill
# Time left: 15.75------ Score: 28 to 21
# 13.617647058823529
# 2PT FG by Nickeil Alexander-Walker
# 3PT FG by Caleb Homesley
# Time left: 15.25------ Score: 30 to 24
# 13.617647058823529
# 3PT FG missed by Ahmed Hill
# Defensive rebound by Elijah Cuffee
# Turnover by Caleb Homesley
# Time left: 14.75------ Score: 30 to 24
# 13.617647058823529
# 3PT FG missed by Ahmed Hill
# Defensive rebound by Scottie James
# 2PT FG missed by Caleb Homesley
# Defensive rebound by Ahmed Hill
# Time left: 14.25------ Score: 30 to 24
# 13.617647058823529
# Turnover by Nickeil Alexander-Walker
# 3PT FG missed by Darius McGhee
# Defensive rebound by Ahmed Hill
# Time left: 13.75------ Score: 30 to 24
# 13.617647058823529
# 2PT FG by Kerry Blackshear Jr.
# Turnover by Scottie James
# Time left: 13.25------ Score: 32 to 24
# 13.617647058823529
# 3PT FG missed by Nickeil Alexander-Walker
# Offensive rebound by Kerry Blackshear Jr.
# Time left: 12.75------ Score: 32 to 24
# 13.617647058823529
# 3PT FG missed by Ahmed Hill
# Defensive rebound by Darius McGhee
# 3PT FG missed by Caleb Homesley
# Defensive rebound by Ty Outlaw
# Time left: 12.25------ Score: 32 to 24
# 13.617647058823529
# 2PT FG missed by Justin Robinson
# Defensive rebound by Lovell Cabbil
# Turnover by Elijah Cuffee
# Time left: 11.75------ Score: 32 to 24
# 13.617647058823529
# 2PT FG by Justin Robinson
# 2PT FG missed by Georgie Pacheco-Ortiz
# Offensive rebound by Scottie James
# Time left: 11.25------ Score: 34 to 24
# 2PT FG missed by Scottie James
# Defensive rebound by Nickeil Alexander-Walker
# Time left: 10.75------ Score: 34 to 24
# 13.617647058823529
# 2PT FG by Ahmed Hill
# 2PT FG missed by Caleb Homesley
# Defensive rebound by Ty Outlaw
# Time left: 10.25------ Score: 36 to 24
# 13.617647058823529
# 2PT FG missed by Kerry Blackshear Jr.
# Offensive rebound by P.J. Horne
# Time left: 9.75------ Score: 36 to 24
# 13.617647058823529
# 3PT FG missed by Isaiah Wilkins
# Defensive rebound by Keegan McDowell
# 2PT FG missed by Myo Baxter-Bell
# Defensive rebound by Justin Robinson
# Time left: 9.25------ Score: 36 to 24
# 13.617647058823529
# Turnover by Justin Robinson
# 2PT FG by Scottie James
# Time left: 8.75------ Score: 36 to 26
# 13.617647058823529
# 2PT FG by Justin Robinson
# Turnover by Elijah Cuffee
# Time left: 8.25------ Score: 38 to 26
# 13.617647058823529
# 3PT FG missed by Justin Robinson
# Defensive rebound by Myo Baxter-Bell
# 3PT FG by Elijah Cuffee
# Time left: 7.75------ Score: 38 to 29
# 13.617647058823529
# Turnover by Justin Robinson
# Turnover by Scottie James
# Time left: 7.25------ Score: 38 to 29
# 13.617647058823529
# Turnover by Nickeil Alexander-Walker
# 3PT FG missed by Myo Baxter-Bell
# Defensive rebound by Nickeil Alexander-Walker
# Time left: 6.75------ Score: 38 to 29
# 13.617647058823529
# 2PT FG by Justin Robinson
# 3PT FG missed by Elijah Cuffee
# Defensive rebound by Ty Outlaw
# Time left: 6.25------ Score: 40 to 29
# 13.617647058823529
# Turnover by Nickeil Alexander-Walker
# 2PT FG missed by Scottie James
# Defensive rebound by Kerry Blackshear Jr.
# Time left: 5.75------ Score: 40 to 29
# 13.617647058823529
# 3PT FG by Ahmed Hill
# 2PT FG missed by Caleb Homesley
# Defensive rebound by Ahmed Hill
# Time left: 5.25------ Score: 43 to 29
# 13.617647058823529
# 2PT FG by Wabissa Bede
# 3PT FG missed by Lovell Cabbil
# Defensive rebound by Ty Outlaw
# Time left: 4.75------ Score: 45 to 29
# 13.617647058823529
# 2PT FG by P.J. Horne
# 3PT FG by Keegan McDowell
# Time left: 4.25------ Score: 47 to 32
# 13.617647058823529
# 2PT FG by P.J. Horne
# Turnover by Scottie James
# Time left: 3.75------ Score: 49 to 32
# 13.617647058823529
# Turnover by Wabissa Bede
# Turnover by Myo Baxter-Bell
# Time left: 3.25------ Score: 49 to 32
# 13.617647058823529
# 2PT FG missed by Kerry Blackshear Jr.
# Defensive rebound by Keegan McDowell
# 3PT FG missed by Caleb Homesley
# Defensive rebound by P.J. Horne
# Time left: 2.75------ Score: 49 to 32
# 13.617647058823529
# 2PT FG by P.J. Horne
# Turnover by Elijah Cuffee
# Time left: 2.25------ Score: 51 to 32
# 13.617647058823529
# 3PT FG by Isaiah Wilkins
# 2PT FG by Scottie James
# Time left: 1.75------ Score: 54 to 34
# 13.617647058823529
# 2PT FG by Ty Outlaw
# 3PT FG missed by Caleb Homesley
# Defensive rebound by Justin Robinson
# Time left: 1.25------ Score: 56 to 34
# 13.617647058823529
# Turnover by Wabissa Bede
# 2PT FG missed by Lovell Cabbil
# Defensive rebound by Ahmed Hill
# Time left: 0.75------ Score: 56 to 34
# 13.617647058823529
# Turnover by Wabissa Bede
# 3PT FG missed by Lovell Cabbil
# Offensive rebound by Scottie James
# Time left: 0.25------ Score: 56 to 34
# 56
# 34
#                         Name  Points  2PM  2PA  3PM  3PA  TOV  ORB  DRB  TRB
# 1   Nickeil Alexander-Walker      13    5    8    1    2    8    1    4    5
# 2       Kerry Blackshear Jr.      11    4    8    1    5    0    4    4    8
# 3            Justin Robinson       6    3    8    0    1    3    1    4    5
# 4                 Ahmed Hill      11    1    2    3    6    0    1    7    8
# 5                  Ty Outlaw       2    1    1    0    0    0    0    8    8
# 6             Isaiah Wilkins       3    0    3    1    4    1    0    0    0
# 7                 P.J. Horne       6    3    5    0    0    0    3    1    4
# 8               Wabissa Bede       4    2    3    0    1    4    1    1    2
# 9           Jonathan Kabongo       0    0    0    0    0    0    0    0    0
# 10            Brendan Palmer       0    0    0    0    0    0    0    0    0
#                      Name  Points  2PM  2PA  3PM  3PA  TOV  ORB  DRB  TRB
# 1           Scottie James       8    4    9    0    2    4    4    4    8
# 2          Caleb Homesley       6    0    3    2    8    2    0    2    2
# 3           Lovell Cabbil       3    0    3    1    4    1    0    2    2
# 4           Elijah Cuffee       6    0    0    2    3    3    0    1    1
# 5           Darius McGhee       6    0    0    2    6    1    1    5    6
# 6   Georgie Pacheco-Ortiz       0    0    2    0    1    1    0    1    1
# 7            Keenan Gumbs       0    0    2    0    0    1    1    1    2
# 8         Myo Baxter-Bell       2    1    5    0    1    5    2    2    4
# 9         Keegan McDowell       3    0    0    1    1    1    0    3    3
# 10         Brendan Newton       0    0    0    0    0    0    0    0    0
# 11          Zach Farquhar       0    0    0    0    0    0    0    0    0
# 13.617647058823529
# 2PT FG missed by Justin Robinson
# Defensive rebound by Lovell Cabbil
# 3PT FG missed by Elijah Cuffee
# Defensive rebound by Isaiah Wilkins
# Time left: 39.75------ Score: 0 to 0
# 13.617647058823529
# 2PT FG missed by Ahmed Hill
# Defensive rebound by Darius McGhee
# 2PT FG missed by Scottie James
# Defensive rebound by Wabissa Bede
# Time left: 39.25------ Score: 0 to 0
# 13.617647058823529
# Turnover by P.J. Horne
# 2PT FG missed by Keenan Gumbs
# Defensive rebound by Ty Outlaw
# Time left: 38.75------ Score: 0 to 0
# 13.617647058823529
# Turnover by Justin Robinson
# 3PT FG by Lovell Cabbil
# Time left: 38.25------ Score: 0 to 3
# 13.617647058823529
# 3PT FG by Justin Robinson
# 2PT FG missed by Caleb Homesley
# Defensive rebound by Ty Outlaw
# Time left: 37.75------ Score: 3 to 3
# 13.617647058823529
# 2PT FG by Ahmed Hill
# Turnover by Myo Baxter-Bell
# Time left: 37.25------ Score: 5 to 3
# 13.617647058823529
# Turnover by Nickeil Alexander-Walker
# 3PT FG missed by Darius McGhee
# Defensive rebound by Ahmed Hill
# Time left: 36.75------ Score: 5 to 3
# 13.617647058823529
# 2PT FG by Ahmed Hill
# 3PT FG by Georgie Pacheco-Ortiz
# Time left: 36.25------ Score: 7 to 6
# 13.617647058823529
# Turnover by Kerry Blackshear Jr.
# 2PT FG by Scottie James
# Time left: 35.75------ Score: 7 to 8
# 13.617647058823529
# 2PT FG missed by P.J. Horne
# Defensive rebound by Darius McGhee
# Turnover by Scottie James
# Time left: 35.25------ Score: 7 to 8
# 13.617647058823529
# 3PT FG by Justin Robinson
# 2PT FG by Scottie James
# Time left: 34.75------ Score: 10 to 10
# 13.617647058823529
# 3PT FG missed by Ahmed Hill
# Defensive rebound by Caleb Homesley
# 2PT FG missed by Lovell Cabbil
# Defensive rebound by Kerry Blackshear Jr.
# Time left: 34.25------ Score: 10 to 10
# 13.617647058823529
# 3PT FG by Ahmed Hill
# 2PT FG missed by Caleb Homesley
# Defensive rebound by Ahmed Hill
# Time left: 33.75------ Score: 13 to 10
# 13.617647058823529
# 2PT FG by Wabissa Bede
# Turnover by Keenan Gumbs
# Time left: 33.25------ Score: 15 to 10
# 13.617647058823529
# 2PT FG missed by Nickeil Alexander-Walker
# Defensive rebound by Caleb Homesley
# 2PT FG by Darius McGhee
# Time left: 32.75------ Score: 15 to 12
# 13.617647058823529
# 3PT FG missed by Nickeil Alexander-Walker
# Offensive rebound by Kerry Blackshear Jr.
# Time left: 32.25------ Score: 15 to 12
# 13.617647058823529
# 2PT FG by Nickeil Alexander-Walker
# 2PT FG missed by Myo Baxter-Bell
# Defensive rebound by Wabissa Bede
# Time left: 31.75------ Score: 17 to 12
# 13.617647058823529
# 2PT FG by Jonathan Kabongo
# 3PT FG missed by Georgie Pacheco-Ortiz
# Defensive rebound by Kerry Blackshear Jr.
# Time left: 31.25------ Score: 19 to 12
# 13.617647058823529
# 2PT FG by Kerry Blackshear Jr.
# 2PT FG missed by Caleb Homesley
# Defensive rebound by Justin Robinson
# Time left: 30.75------ Score: 21 to 12
# 13.617647058823529
# 2PT FG missed by Ahmed Hill
# Offensive rebound by Kerry Blackshear Jr.
# Time left: 30.25------ Score: 21 to 12
# 13.617647058823529
# Turnover by Wabissa Bede
# Turnover by Lovell Cabbil
# Time left: 29.75------ Score: 21 to 12
# 13.617647058823529
# 2PT FG by Justin Robinson
# 2PT FG missed by Myo Baxter-Bell
# Offensive rebound by Myo Baxter-Bell
# Time left: 29.25------ Score: 23 to 12
# Turnover by Elijah Cuffee
# Time left: 28.75------ Score: 23 to 12
# 13.617647058823529
# 2PT FG missed by Wabissa Bede
# Defensive rebound by Caleb Homesley
# 3PT FG missed by Caleb Homesley
# Defensive rebound by Ty Outlaw
# Time left: 28.25------ Score: 23 to 12
# 13.617647058823529
# 2PT FG missed by Kerry Blackshear Jr.
# Defensive rebound by Caleb Homesley
# 2PT FG missed by Myo Baxter-Bell
# Defensive rebound by Ty Outlaw
# Time left: 27.75------ Score: 23 to 12
# 13.617647058823529
# 3PT FG by Isaiah Wilkins
# 2PT FG missed by Myo Baxter-Bell
# Defensive rebound by Nickeil Alexander-Walker
# Time left: 27.25------ Score: 26 to 12
# 13.617647058823529
# 2PT FG missed by Justin Robinson
# Offensive rebound by Ty Outlaw
# Time left: 26.75------ Score: 26 to 12
# 13.617647058823529
# 2PT FG missed by Justin Robinson
# Defensive rebound by Darius McGhee
# 2PT FG missed by Caleb Homesley
# Defensive rebound by Justin Robinson
# Time left: 26.25------ Score: 26 to 12
# 13.617647058823529
# 2PT FG missed by P.J. Horne
# Offensive rebound by Ty Outlaw
# Time left: 25.75------ Score: 26 to 12
# 13.617647058823529
# 2PT FG by P.J. Horne
# 3PT FG by Keegan McDowell
# Time left: 25.25------ Score: 28 to 15
# 13.617647058823529
# 3PT FG by Ty Outlaw
# 3PT FG missed by Georgie Pacheco-Ortiz
# Defensive rebound by Kerry Blackshear Jr.
# Time left: 24.75------ Score: 31 to 15
# 13.617647058823529
# 2PT FG missed by Nickeil Alexander-Walker
# Defensive rebound by Scottie James
# Turnover by Scottie James
# Time left: 24.25------ Score: 31 to 15
# 13.617647058823529
# 2PT FG by Isaiah Wilkins
# 2PT FG by Caleb Homesley
# Time left: 23.75------ Score: 33 to 17
# 13.617647058823529
# Turnover by Nickeil Alexander-Walker
# 3PT FG missed by Darius McGhee
# Defensive rebound by Isaiah Wilkins
# Time left: 23.25------ Score: 33 to 17
# 13.617647058823529
# 2PT FG missed by P.J. Horne
# Offensive rebound by Ty Outlaw
# Time left: 22.75------ Score: 33 to 17
# 13.617647058823529
# 3PT FG missed by Ahmed Hill
# Defensive rebound by Keegan McDowell
# 2PT FG missed by Keegan McDowell
# Defensive rebound by P.J. Horne
# Time left: 22.25------ Score: 33 to 17
# 13.617647058823529
# 3PT FG missed by Justin Robinson
# Defensive rebound by Keenan Gumbs
# Turnover by Scottie James
# Time left: 21.75------ Score: 33 to 17
# 13.617647058823529
# Turnover by Ahmed Hill
# 3PT FG missed by Caleb Homesley
# Defensive rebound by Kerry Blackshear Jr.
# Time left: 21.25------ Score: 33 to 17
# 13.617647058823529
# Turnover by Nickeil Alexander-Walker
# Turnover by Caleb Homesley
# Time left: 20.75------ Score: 33 to 17
# 13.617647058823529
# 2PT FG missed by Justin Robinson
# Offensive rebound by Kerry Blackshear Jr.
# Time left: 20.25------ Score: 33 to 17
# 13.617647058823529
# 3PT FG missed by Nickeil Alexander-Walker
# Offensive rebound by Ty Outlaw
# Time left: 19.75------ Score: 33 to 17
# 13.617647058823529
# 2PT FG missed by Kerry Blackshear Jr.
# Offensive rebound by Ty Outlaw
# Time left: 19.25------ Score: 33 to 17
# 13.617647058823529
# 3PT FG missed by Kerry Blackshear Jr.
# Defensive rebound by Scottie James
# 3PT FG missed by Scottie James
# Defensive rebound by Kerry Blackshear Jr.
# Time left: 18.75------ Score: 33 to 17
# 13.617647058823529
# 2PT FG by Ahmed Hill
# 2PT FG missed by Scottie James
# Defensive rebound by Isaiah Wilkins
# Time left: 18.25------ Score: 35 to 17
# 13.617647058823529
# Turnover by Isaiah Wilkins
# 2PT FG missed by Darius McGhee
# Offensive rebound by Scottie James
# Time left: 17.75------ Score: 35 to 17
# 3PT FG by Caleb Homesley
# Time left: 17.25------ Score: 35 to 20
# 13.617647058823529
# 3PT FG missed by Justin Robinson
# Defensive rebound by Keegan McDowell
# 2PT FG by Caleb Homesley
# Time left: 16.75------ Score: 35 to 22
# 13.617647058823529
# 3PT FG missed by Ahmed Hill
# Offensive rebound by P.J. Horne
# Time left: 16.25------ Score: 35 to 22
# 13.617647058823529
# 2PT FG by Justin Robinson
# 3PT FG missed by Elijah Cuffee
# Offensive rebound by Keegan McDowell
# Time left: 15.75------ Score: 37 to 22
# 2PT FG missed by Caleb Homesley
# Defensive rebound by Justin Robinson
# Time left: 15.25------ Score: 37 to 22
# 13.617647058823529
# 2PT FG missed by Nickeil Alexander-Walker
# Defensive rebound by Lovell Cabbil
# 3PT FG missed by Scottie James
# Defensive rebound by Isaiah Wilkins
# Time left: 14.75------ Score: 37 to 22
# 13.617647058823529
# 3PT FG by Nickeil Alexander-Walker
# 2PT FG missed by Myo Baxter-Bell
# Offensive rebound by Scottie James
# Time left: 14.25------ Score: 40 to 22
# 2PT FG missed by Scottie James
# Defensive rebound by Nickeil Alexander-Walker
# Time left: 13.75------ Score: 40 to 22
# 13.617647058823529
# 3PT FG by Ahmed Hill
# 2PT FG missed by Caleb Homesley
# Defensive rebound by Wabissa Bede
# Time left: 13.25------ Score: 43 to 22
# 13.617647058823529
# Turnover by Justin Robinson
# 2PT FG by Scottie James
# Time left: 12.75------ Score: 43 to 24
# 13.617647058823529
# 3PT FG missed by Ty Outlaw
# Defensive rebound by Myo Baxter-Bell
# 2PT FG missed by Elijah Cuffee
# Defensive rebound by Ty Outlaw
# Time left: 12.25------ Score: 43 to 24
# 13.617647058823529
# 3PT FG missed by Ahmed Hill
# Defensive rebound by Scottie James
# 2PT FG by Darius McGhee
# Time left: 11.75------ Score: 43 to 26
# 13.617647058823529
# 3PT FG missed by Justin Robinson
# Defensive rebound by Scottie James
# 2PT FG missed by Georgie Pacheco-Ortiz
# Defensive rebound by Justin Robinson
# Time left: 11.25------ Score: 43 to 26
# 13.617647058823529
# 3PT FG by Ahmed Hill
# 2PT FG missed by Scottie James
# Defensive rebound by Ty Outlaw
# Time left: 10.75------ Score: 46 to 26
# 13.617647058823529
# 2PT FG by Justin Robinson
# Turnover by Elijah Cuffee
# Time left: 10.25------ Score: 48 to 26
# 13.617647058823529
# 2PT FG by Kerry Blackshear Jr.
# 3PT FG missed by Caleb Homesley
# Defensive rebound by Kerry Blackshear Jr.
# Time left: 9.75------ Score: 50 to 26
# 13.617647058823529
# 2PT FG missed by Justin Robinson
# Offensive rebound by Kerry Blackshear Jr.
# Time left: 9.25------ Score: 50 to 26
# 13.617647058823529
# 3PT FG by Ahmed Hill
# ...
# 5                  Ty Outlaw      16    2    3    4    9    1    2    6    8
# 6             Isaiah Wilkins       4    2    2    0    0    1    1    3    4
# 7                 P.J. Horne       4    2    2    0    0    3    2    1    3
# 8               Wabissa Bede       0    0    0    0    0    3    0    3    3
# 9           Jonathan Kabongo       0    0    0    0    2    0    0    0    0
# 10            Brendan Palmer       0    0    0    0    0    0    0    0    0
#                      Name  Points  2PM  2PA  3PM  3PA  TOV  ORB  DRB  TRB
# 1           Scottie James       8    4    7    0    0    3    3    4    7
# 2          Caleb Homesley       2    1    8    0    5    2    0   10   10
# 3           Lovell Cabbil       3    0    4    1    1    5    0    5    5
# 4           Elijah Cuffee       2    1    3    0    4    1    0    1    1
# 5           Darius McGhee       9    0    3    3    8    1    0    2    2
# 6   Georgie Pacheco-Ortiz       0    0    2    0    0    1    0    1    1
# 7            Keenan Gumbs       0    0    1    0    4    2    2    1    3
# 8         Myo Baxter-Bell       2    1    2    0    0    2    1    0    1
# 9         Keegan McDowell       3    0    1    1    2    0    0    0    0
# 10         Brendan Newton       0    0    0    0    0    2    0    3    3
# 11          Zach Farquhar       0    0    0    0    0    0    0    0    0
# 13.617647058823529
# 2PT FG missed by Kerry Blackshear Jr.
# Offensive rebound by Kerry Blackshear Jr.
# Time left: 39.75------ Score: 0 to 0
# 13.617647058823529
# 2PT FG missed by Nickeil Alexander-Walker
# Defensive rebound by Keegan McDowell
# 2PT FG missed by Scottie James
# Defensive rebound by P.J. Horne
# Time left: 39.25------ Score: 0 to 0
# 13.617647058823529
# Turnover by Ahmed Hill
# 2PT FG by Keenan Gumbs
# Time left: 38.75------ Score: 0 to 2
# 13.617647058823529
# 2PT FG by Nickeil Alexander-Walker
# 3PT FG missed by Elijah Cuffee
# Defensive rebound by Isaiah Wilkins
# Time left: 38.25------ Score: 2 to 2
# 13.617647058823529
# Turnover by Justin Robinson
# 2PT FG missed by Brendan Newton
# Defensive rebound by Jonathan Kabongo
# Time left: 37.75------ Score: 2 to 2
# 13.617647058823529
# 3PT FG by Ahmed Hill
# 2PT FG by Georgie Pacheco-Ortiz
# Time left: 37.25------ Score: 5 to 4
# 13.617647058823529
# Turnover by Nickeil Alexander-Walker
# 3PT FG by Caleb Homesley
# Time left: 36.75------ Score: 5 to 7
# 13.617647058823529
# 2PT FG missed by Ahmed Hill
# Defensive rebound by Scottie James
# Turnover by Elijah Cuffee
# Time left: 36.25------ Score: 5 to 7
# 13.617647058823529
# 2PT FG by Isaiah Wilkins
# 2PT FG missed by Keenan Gumbs
# Defensive rebound by Kerry Blackshear Jr.
# Time left: 35.75------ Score: 7 to 7
# 13.617647058823529
# 3PT FG missed by Wabissa Bede
# Offensive rebound by Kerry Blackshear Jr.
# Time left: 35.25------ Score: 7 to 7
# 13.617647058823529
# Turnover by Wabissa Bede
# 3PT FG by Elijah Cuffee
# Time left: 34.75------ Score: 7 to 10
# 13.617647058823529
# 2PT FG by Kerry Blackshear Jr.
# 3PT FG by Georgie Pacheco-Ortiz
# Time left: 34.25------ Score: 9 to 13
# 13.617647058823529
# 2PT FG missed by Ty Outlaw
# Defensive rebound by Myo Baxter-Bell
# Turnover by Lovell Cabbil
# Time left: 33.75------ Score: 9 to 13
# 13.617647058823529
# 2PT FG missed by Kerry Blackshear Jr.
# Offensive rebound by Ahmed Hill
# Time left: 33.25------ Score: 9 to 13
# 13.617647058823529
# 3PT FG missed by Ahmed Hill
# Offensive rebound by Kerry Blackshear Jr.
# Time left: 32.75------ Score: 9 to 13
# 13.617647058823529
# 3PT FG missed by Nickeil Alexander-Walker
# Defensive rebound by Scottie James
# 3PT FG by Darius McGhee
# Time left: 32.25------ Score: 9 to 16
# 13.617647058823529
# 2PT FG missed by Justin Robinson
# Offensive rebound by P.J. Horne
# Time left: 31.75------ Score: 9 to 16
# 13.617647058823529
# 3PT FG missed by Isaiah Wilkins
# Defensive rebound by Caleb Homesley
# 2PT FG missed by Georgie Pacheco-Ortiz
# Defensive rebound by Ahmed Hill
# Time left: 31.25------ Score: 9 to 16
# 13.617647058823529
# 3PT FG missed by Nickeil Alexander-Walker
# Defensive rebound by Lovell Cabbil
# 3PT FG missed by Darius McGhee
# Defensive rebound by Ty Outlaw
# Time left: 30.75------ Score: 9 to 16
# 13.617647058823529
# 3PT FG missed by Justin Robinson
# Defensive rebound by Darius McGhee
# Turnover by Lovell Cabbil
# Time left: 30.25------ Score: 9 to 16
# 13.617647058823529
# 2PT FG missed by Kerry Blackshear Jr.
# Offensive rebound by Justin Robinson
# Time left: 29.75------ Score: 9 to 16
# 13.617647058823529
# 2PT FG by Jonathan Kabongo
# Turnover by Myo Baxter-Bell
# Time left: 29.25------ Score: 11 to 16
# 13.617647058823529
# 3PT FG missed by Ahmed Hill
# Defensive rebound by Lovell Cabbil
# 2PT FG by Scottie James
# Time left: 28.75------ Score: 11 to 18
# 13.617647058823529
# 3PT FG missed by Ty Outlaw
# Offensive rebound by Justin Robinson
# Time left: 28.25------ Score: 11 to 18
# 13.617647058823529
# Turnover by Nickeil Alexander-Walker
# 3PT FG missed by Lovell Cabbil
# Defensive rebound by Ty Outlaw
# Time left: 27.75------ Score: 11 to 18
# 13.617647058823529
# 2PT FG missed by Isaiah Wilkins
# Defensive rebound by Caleb Homesley
# 3PT FG missed by Darius McGhee
# Defensive rebound by Isaiah Wilkins
# Time left: 27.25------ Score: 11 to 18
# 13.617647058823529
# 3PT FG missed by Justin Robinson
# Offensive rebound by Isaiah Wilkins
# Time left: 26.75------ Score: 11 to 18
# 13.617647058823529
# 2PT FG by Ahmed Hill
# 2PT FG missed by Myo Baxter-Bell
# Defensive rebound by Wabissa Bede
# Time left: 26.25------ Score: 13 to 18
# 13.617647058823529
# 3PT FG by Nickeil Alexander-Walker
# 3PT FG by Darius McGhee
# Time left: 25.75------ Score: 16 to 21
# 13.617647058823529
# 3PT FG missed by Nickeil Alexander-Walker
# Defensive rebound by Darius McGhee
# 3PT FG by Caleb Homesley
# Time left: 25.25------ Score: 16 to 24
# 13.617647058823529
# 2PT FG by Justin Robinson
# Turnover by Keenan Gumbs
# Time left: 24.75------ Score: 18 to 24
# 13.617647058823529
# Turnover by Kerry Blackshear Jr.
# 2PT FG missed by Scottie James
# Defensive rebound by P.J. Horne
# Time left: 24.25------ Score: 18 to 24
# 13.617647058823529
# Turnover by P.J. Horne
# 2PT FG missed by Keenan Gumbs
# Defensive rebound by Justin Robinson
# Time left: 23.75------ Score: 18 to 24
# 13.617647058823529
# 3PT FG by Ahmed Hill
# 3PT FG missed by Darius McGhee
# Defensive rebound by Ty Outlaw
# Time left: 23.25------ Score: 21 to 24
# 13.617647058823529
# 3PT FG missed by Justin Robinson
# Defensive rebound by Keenan Gumbs
# 2PT FG missed by Myo Baxter-Bell
# Defensive rebound by Kerry Blackshear Jr.
# Time left: 22.75------ Score: 21 to 24
# 13.617647058823529
# 3PT FG by Isaiah Wilkins
# Turnover by Keenan Gumbs
# Time left: 22.25------ Score: 24 to 24
# 13.617647058823529
# 2PT FG missed by Justin Robinson
# Defensive rebound by Scottie James
# Turnover by Myo Baxter-Bell
# Time left: 21.75------ Score: 24 to 24
# 13.617647058823529
# Turnover by Ahmed Hill
# 2PT FG missed by Scottie James
# Defensive rebound by Isaiah Wilkins
# Time left: 21.25------ Score: 24 to 24
# 13.617647058823529
# 2PT FG missed by Wabissa Bede
# Defensive rebound by Darius McGhee
# Turnover by Lovell Cabbil
# Time left: 20.75------ Score: 24 to 24
# 13.617647058823529
# 3PT FG missed by Isaiah Wilkins
# Offensive rebound by P.J. Horne
# Time left: 20.25------ Score: 24 to 24
# 13.617647058823529
# 3PT FG missed by Ty Outlaw
# Defensive rebound by Caleb Homesley
# 3PT FG missed by Darius McGhee
# Defensive rebound by Kerry Blackshear Jr.
# Time left: 19.75------ Score: 24 to 24
# 13.617647058823529
# Turnover by Kerry Blackshear Jr.
# 2PT FG missed by Lovell Cabbil
# Defensive rebound by Ty Outlaw
# Time left: 19.25------ Score: 24 to 24
# 13.617647058823529
# 3PT FG missed by Ahmed Hill
# Defensive rebound by Caleb Homesley
# 3PT FG missed by Caleb Homesley
# Defensive rebound by Justin Robinson
# Time left: 18.75------ Score: 24 to 24
# 13.617647058823529
# 3PT FG missed by Ty Outlaw
# Defensive rebound by Scottie James
# 3PT FG missed by Lovell Cabbil
# Offensive rebound by Lovell Cabbil
# Time left: 18.25------ Score: 24 to 24
# 2PT FG missed by Lovell Cabbil
# Defensive rebound by Ty Outlaw
# Time left: 17.75------ Score: 24 to 24
# 13.617647058823529
# 3PT FG by Justin Robinson
# 2PT FG missed by Caleb Homesley
# Defensive rebound by Isaiah Wilkins
# Time left: 17.25------ Score: 27 to 24
# 13.617647058823529
# 3PT FG missed by Jonathan Kabongo
# Defensive rebound by Elijah Cuffee
# Turnover by Lovell Cabbil
# Time left: 16.75------ Score: 27 to 24
# 13.617647058823529
# Turnover by Nickeil Alexander-Walker
# Turnover by Caleb Homesley
# Time left: 16.25------ Score: 27 to 24
# 13.617647058823529
# 3PT FG missed by Ahmed Hill
# Defensive rebound by Elijah Cuffee
# 3PT FG missed by Keegan McDowell
# Defensive rebound by Kerry Blackshear Jr.
# Time left: 15.75------ Score: 27 to 24
# 13.617647058823529
# 3PT FG missed by Justin Robinson
# Defensive rebound by Myo Baxter-Bell
# 2PT FG missed by Caleb Homesley
# Offensive rebound by Caleb Homesley
# Time left: 15.25------ Score: 27 to 24
# 3PT FG missed by Lovell Cabbil
# Defensive rebound by Ahmed Hill
# Time left: 14.75------ Score: 27 to 24
# 13.617647058823529
# 3PT FG by Nickeil Alexander-Walker
# 2PT FG missed by Keegan McDowell
# Defensive rebound by Wabissa Bede
# Time left: 14.25------ Score: 30 to 24
# 13.617647058823529
# 3PT FG missed by Nickeil Alexander-Walker
# Defensive rebound by Darius McGhee
# 3PT FG missed by Caleb Homesley
# Offensive rebound by Keenan Gumbs
# Time left: 13.75------ Score: 30 to 24
# 2PT FG by Scottie James
# Time left: 13.25------ Score: 30 to 26
# 13.617647058823529
# 3PT FG by Ahmed Hill
# 2PT FG missed by Lovell Cabbil
# Defensive rebound by P.J. Horne
# Time left: 12.75------ Score: 33 to 26
# 13.617647058823529
# Turnover by Ahmed Hill
# 2PT FG by Scottie James
# Time left: 12.25------ Score: 33 to 28
# 13.617647058823529
# 2PT FG by Nickeil Alexander-Walker
# Turnover by Caleb Homesley
# Time left: 11.75------ Score: 35 to 28
# 13.617647058823529
# 2PT FG missed by Wabissa Bede
# Defensive rebound by Lovell Cabbil
# Turnover by Elijah Cuffee
# Time left: 11.25------ Score: 35 to 28
# 13.617647058823529
# 3PT FG by Ty Outlaw
# 3PT FG by Lovell Cabbil
# Time left: 10.75------ Score: 38 to 31
# 13.617647058823529
# 2PT FG by Justin Robinson
# Turnover by Keegan McDowell
# Time left: 10.25------ Score: 40 to 31
# 13.617647058823529
# 3PT FG missed by Ahmed Hill
# Defensive rebound by Caleb Homesley
# 2PT FG missed by Caleb Homesley
# Defensive rebound by Ty Outlaw
# Time left: 9.75------ Score: 40 to 31
# 13.617647058823529
# 2PT FG missed by Ahmed Hill
# Defensive rebound by Darius McGhee
# Turnover by Lovell Cabbil
# Time left: 9.25------ Score: 40 to 31
# 13.617647058823529
# 2PT FG by Kerry Blackshear Jr.
# 2PT FG missed by Caleb Homesley
# Offensive rebound by Scottie James
# Time left: 8.75------ Score: 42 to 31
# Turnover by Caleb Homesley
# Time left: 8.25------ Score: 42 to 31
# 13.617647058823529
# Turnover by Justin Robinson
# 3PT FG by Keenan Gumbs
# Time left: 7.75------ Score: 42 to 34
# 13.617647058823529
# 3PT FG by Ty Outlaw
# 3PT FG missed by Darius McGhee
# Defensive rebound by Ty Outlaw
# Time left: 7.25------ Score: 45 to 34
# 13.617647058823529
# 2PT FG by Kerry Blackshear Jr.
# 2PT FG missed by Caleb Homesley
# Defensive rebound by Kerry Blackshear Jr.
# Time left: 6.75------ Score: 47 to 34
# 13.617647058823529
# 3PT FG missed by Justin Robinson
# Offensive rebound by Ty Outlaw
# Time left: 6.25------ Score: 47 to 34
# 13.617647058823529
# 2PT FG missed by Justin Robinson
# Defensive rebound by Caleb Homesley
# 3PT FG missed by Caleb Homesley
# Defensive rebound by Wabissa Bede
# Time left: 5.75------ Score: 47 to 34
# 13.617647058823529
# 2PT FG missed by Justin Robinson
# Defensive rebound by Myo Baxter-Bell
# Turnover by Keegan McDowell
# Time left: 5.25------ Score: 47 to 34
# 13.617647058823529
# Turnover by Nickeil Alexander-Walker
# 3PT FG by Elijah Cuffee
# Time left: 4.75------ Score: 47 to 37
# 13.617647058823529
# 2PT FG by Nickeil Alexander-Walker
# 2PT FG by Scottie James
# Time left: 4.25------ Score: 49 to 39
# 13.617647058823529
# Turnover by Nickeil Alexander-Walker
# 3PT FG missed by Lovell Cabbil
# Offensive rebound by Caleb Homesley
# Time left: 3.75------ Score: 49 to 39
# 3PT FG missed by Darius McGhee
# Defensive rebound by Ty Outlaw
# Time left: 3.25------ Score: 49 to 39
# 13.617647058823529
# 3PT FG by Ahmed Hill
# Turnover by Darius McGhee
# Time left: 2.75------ Score: 52 to 39
# 13.617647058823529
# Turnover by P.J. Horne
# 2PT FG missed by Darius McGhee
# Defensive rebound by P.J. Horne
# Time left: 2.25------ Score: 52 to 39
# 13.617647058823529
# Turnover by Ahmed Hill
# 3PT FG by Keegan McDowell
# Time left: 1.75------ Score: 52 to 42
# 13.617647058823529
# 3PT FG missed by Wabissa Bede
# Defensive rebound by Myo Baxter-Bell
# Turnover by Scottie James
# Time left: 1.25------ Score: 52 to 42
# 13.617647058823529
# 2PT FG by Ahmed Hill
# 3PT FG by Lovell Cabbil
# Time left: 0.75------ Score: 54 to 45
# 13.617647058823529
# 2PT FG missed by P.J. Horne
# Defensive rebound by Caleb Homesley
# Turnover by Georgie Pacheco-Ortiz
# Time left: 0.25------ Score: 54 to 45
# 54
# 45
#                         Name  Points  2PM  2PA  3PM  3PA  TOV  ORB  DRB  TRB
# 1   Nickeil Alexander-Walker      12    3    4    2    6    5    0    0    0
# 2       Kerry Blackshear Jr.       6    3    6    0    0    2    3    5    8
# 3            Justin Robinson       7    2    6    1    6    2    2    2    4
# 4                 Ahmed Hill      16    2    4    4    9    4    1    2    3
# 5                  Ty Outlaw       6    0    1    2    5    0    1    8    9
# 6             Isaiah Wilkins       5    1    2    1    3    0    1    4    5
# 7                 P.J. Horne       0    0    1    0    0    2    2    4    6
# 8               Wabissa Bede       0    0    2    0    2    1    0    3    3
# 9           Jonathan Kabongo       2    1    1    0    1    0    0    1    1
# 10            Brendan Palmer       0    0    0    0    0    0    0    0    0
#                      Name  Points  2PM  2PA  3PM  3PA  TOV  ORB  DRB  TRB
# 1           Scottie James       8    4    7    0    0    1    1    4    5
# 2          Caleb Homesley       6    0    5    2    5    3    2    7    9
# 3           Lovell Cabbil       6    0    3    2    6    5    1    3    4
# 4           Elijah Cuffee       6    0    0    2    3    2    0    2    2
# 5           Darius McGhee       6    0    1    2    8    1    0    5    5
# 6   Georgie Pacheco-Ortiz       5    1    2    1    1    1    0    0    0
# 7            Keenan Gumbs       5    1    3    1    1    2    1    1    2
# 8         Myo Baxter-Bell       0    0    2    0    0    2    0    4    4
# 9         Keegan McDowell       3    0    1    1    2    2    0    1    1
# 10         Brendan Newton       0    0    1    0    0    0    0    0    0
# 11          Zach Farquhar       0    0    0    0    0    0    0    0    0
# ['virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'liberty', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'liberty', 'virginia-tech', 'virginia-tech', 'liberty', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'liberty', 'virginia-tech', 'liberty', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'liberty', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'liberty', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'liberty', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'liberty', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'liberty', 'virginia-tech', 'liberty', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'liberty', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'liberty', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech', 'virginia-tech']
